# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
import json
import os

# %% [markdown]
# # Import core data from Coursera Catalog API

# %%
# import raw json data from Coursera Catalog API
response = requests.get("https://api.coursera.org/api/courses.v1?limit=100000&includes=instructorIds,partnerIds&fields=instructorIds,partnerIds,courseType,primaryLanguages,subtitleLanguages,certificates,description,startDate,specializations,domainTypes,s12nIds").text 
# API documentation: https://build.coursera.org/app-platform/catalog/
response_info = json.loads(response) # a dictionary
response_info["elements"][0:5]
# Out:
# [{'courseType': 'v2.ondemand',
#   's12nIds': [],
#   'description': 'In this two-hour, project-based course, we introduce Unity\'s powerful animation tool. You\'ll learn about different animations and effects that you can apply to pick-up objects to make them more noticeable and give your game a more polished look. This project covers recording and playing simple animations, basic customization of particle effects, and playing the particle effects when certain events occur in your game.\n\nThe guided project will introduce you to the following Unity concepts:\n- Animations\n- Particle Effects\n- Triggers\n- Coding techniques such as OnTrigger events and invoking methods\n\nThis is a stand-alone guided project, but is also Part 1 in a two-part series introducing Unity\'s animation features. Part 2 will cover using the Animation Window to create trigger transitions between multiple animations on a single GameObject.\n\nThis guided project and series also serve as an optional but recommended foundation for the "FPS Weapon" series.\n\nThis project makes use of the camera movement script written in Create Keyboard Movement Mechanics with C# in Unity and the concepts introduced in Create Power-Ups and Obstacles with C# in Unity. These compliment this guided project and, although not prerequisites, are recommended for a more well-rounded understanding of the concepts presented herein.',
#   'domainTypes': [{'domainId': 'computer-science',
#     'subdomainId': 'software-development'}],
#   'id': 'NJSdGN71Eeq4CApSN3OTvQ',
#   'slug': 'make-pick-ups-look-cool-unity-introduction-animation-1',
#   'instructorIds': ['4730641'],
#   'specializations': [],
#   'primaryLanguages': ['en'],
#   'partnerIds': ['565'],
#   'certificates': ['VerifiedCert'],
#   'name': 'Make Your Pick-Ups Look Cool in Unity (Intro to Animation 1)',
#   'subtitleLanguages': [],
#   'startDate': 1598035773172},
#  {'courseType': 'v2.ondemand',
#   's12nIds': [],
#   'description': 'À la fin de ce projet, vous aurez toutes les compétences de base pour intégrer des applications dans votre Dashboard Hootsuite. Vous serez en mesure de découvrir les différents types d’applications que vous pouvez installer et vous pourrez les intégrer facilement et rapidement à votre tableau de bord sur Hootsuite.',
#   'domainTypes': [{'domainId': 'business', 'subdomainId': 'marketing'},
#    {'subdomainId': 'design-and-product', 'domainId': 'computer-science'}],
#   'id': 'DMkcgX7LEeyRTg6FtAvfBw',
#   'slug': 'integrer-applications-dashboard-hootsuite',
#   'instructorIds': ['26958800'],
#   'specializations': [],
#   'primaryLanguages': ['fr'],
#   'partnerIds': ['565'],
#   'certificates': ['VerifiedCert'],
#   'name': 'Intégrer des applications dans votre Dashboard Hootsuite',
#   'subtitleLanguages': [],
#   'startDate': 1644614698077},
#  {'courseType': 'v2.ondemand',
#   's12nIds': [],
#   'description': 'ينشئ العديد من الأشخاص حسابات وسائط اجتماعية متعددة ويجدون لاحقا أنه من الصعب جدا تحديث ملفاتهم الشخصية على جميع المواقع.\nولذلك ستكون هذه الدورة التدريبية عبارة عن دراسة تمهيدية عن التطبيق هووتسويت، حيث سنتعرف على كيفية إنشاء حساب مجاني، كما سنتعلم كيفية استخدام موقع هووتسويت وطبيعته وميزاته المتقدمة.\n\nفي نهاية هذه الدورة ستكون قادرا على إنشاء حسابا مجانيا وستكون لديك دراية شاملة على الواجهة الإلكترونية لهووتسويت ومميزات وخصائص هذا التطبيق.\n\nفي هذا المشروع، سنقدم لك مراجعة تفصيلية للميزات الي يقدمها هووتسويت لإدارة فعالة لوسائل التواصل الاجتماعي. الهدف هو مساعدتك في اتخاذ قرار مستنير حول ما إذا كان هووتسويت مناسب لمتطلبات إدارة لوسائط الاجتماعية الخاصة بك.\nبإكمال هذه الدورة التدريبية عن هووتسويت، وبمجرد اكتمال هذا المشروع سيكون بإمكانك الاتصال بجميع بروفايلاتك على مواقع التواصل الاجتماعي.\n\nملاحظة: تعمل هذه الدورة التدريبية بشكل أفضل للمتعلمين المقيمين في منطقة أمريكا الشمالية، نعمل حاليا على توفير نفس التجربة في مناطق أخرى.',
#   'domainTypes': [{'domainId': 'business', 'subdomainId': 'marketing'},
#    {'domainId': 'business', 'subdomainId': 'business-strategy'}],
#   'id': 'YLO0oGSUEeyIUg4Qv2RsBQ',
#   'slug': 'getting-started-with-hootsuite-ar',
#   'instructorIds': ['76377122'],
#   'specializations': [],
#   'primaryLanguages': ['ar'],
#   'partnerIds': ['565'],
#   'certificates': ['VerifiedCert'],
#   'name': 'كيفية استعمال التطبيق هووتسويت',
#   'subtitleLanguages': [],
#   'startDate': 1642193091376},
#  {'courseType': 'v2.ondemand',
#   's12nIds': [],
#   'description': "Gamification is the application of game elements and digital game design techniques to non-game problems, such as business and social impact challenges. This course will teach you the mechanisms of gamification, why it has such tremendous potential, and how to use it effectively. For additional information on the concepts described in the course, you can purchase Professor Werbach's book For the Win: How Game Thinking Can Revolutionize Your Business in print or ebook format in several languages.",
#   'domainTypes': [{'subdomainId': 'design-and-product',
#     'domainId': 'computer-science'},
#    {'domainId': 'business', 'subdomainId': 'marketing'}],
#   'id': '69Bku0KoEeWZtA4u62x6lQ',
#   'slug': 'gamification',
#   'instructorIds': ['226710'],
#   'specializations': [],
#   'primaryLanguages': ['en'],
#   'partnerIds': ['6'],
#   'certificates': ['VerifiedCert'],
#   'name': 'Gamification',
#   'subtitleLanguages': ['ar',
#    'fr',
#    'uk',
#    'pt-PT',
#    'zh-CN',
#    'it',
#    'pt-BR',
#    'vi',
#    'de',
#    'ru',
#    'tr',
#    'es',
#    'kk'],
#   'startDate': 1447095621493},
#  {'courseType': 'v2.ondemand',
#   's12nIds': ['eYmv6d_7EeWOdA7Ea609SQ'],
#   'description': 'This course will cover the steps used in weighting sample surveys, including methods for adjusting for nonresponse and using data external to the survey for calibration.  Among the techniques discussed are adjustments using estimated response propensities, poststratification, raking, and general regression estimation.  Alternative techniques for imputing values for missing items will be discussed.  For both weighting and imputation, the capabilities of different statistical software packages will be covered, including R®, Stata®, and SAS®.',
#   'domainTypes': [{'subdomainId': 'data-analysis', 'domainId': 'data-science'},
#    {'domainId': 'social-sciences', 'subdomainId': 'governance-and-society'}],
#   'id': '0HiU7Oe4EeWTAQ4yevf_oQ',
#   'slug': 'missing-data',
#   'instructorIds': ['8394050'],
#   'specializations': [],
#   'primaryLanguages': ['en'],
#   'partnerIds': ['32'],
#   'certificates': ['VerifiedCert', 'Specialization'],
#   'name': 'Dealing With Missing Data',
#   'subtitleLanguages': ['es'],
#   'startDate': 1471901099812}]

# %%
# convert from json-like dict to pd dataframe
df = pd.DataFrame.from_dict(response_info["elements"])
print(len(df))
print(df.dtypes)
df.head()
# Out:
# 9507
# courseType           object
# s12nIds              object
# description          object
# domainTypes          object
# id                   object
# slug                 object
# instructorIds        object
# specializations      object
# primaryLanguages     object
# partnerIds           object
# certificates         object
# name                 object
# subtitleLanguages    object
# startDate             int64
# dtype: object
#     courseType                   s12nIds  \
# 0  v2.ondemand                        []
# 1  v2.ondemand                        []
# 2  v2.ondemand                        []
# 3  v2.ondemand                        []
# 4  v2.ondemand  [eYmv6d_7EeWOdA7Ea609SQ]
#
#                                          description  \
# 0  In this two-hour, project-based course, we int...
# 1  À la fin de ce projet, vous aurez toutes les c...
# 2  ينشئ العديد من الأشخاص حسابات وسائط اجتماعية م...
# 3  Gamification is the application of game elemen...
# 4  This course will cover the steps used in weigh...
#
#                                          domainTypes                      id  \
# 0  [{'domainId': 'computer-science', 'subdomainId...  NJSdGN71Eeq4CApSN3OTvQ
# 1  [{'domainId': 'business', 'subdomainId': 'mark...  DMkcgX7LEeyRTg6FtAvfBw
# 2  [{'domainId': 'business', 'subdomainId': 'mark...  YLO0oGSUEeyIUg4Qv2RsBQ
# 3  [{'subdomainId': 'design-and-product', 'domain...  69Bku0KoEeWZtA4u62x6lQ
# 4  [{'subdomainId': 'data-analysis', 'domainId': ...  0HiU7Oe4EeWTAQ4yevf_oQ
#
#                                                 slug instructorIds  \
# 0  make-pick-ups-look-cool-unity-introduction-ani...     [4730641]
# 1          integrer-applications-dashboard-hootsuite    [26958800]
# 2                  getting-started-with-hootsuite-ar    [76377122]
# 3                                       gamification      [226710]
# 4                                       missing-data     [8394050]
#
#   specializations primaryLanguages partnerIds                    certificates  \
# 0              []             [en]      [565]                  [VerifiedCert]
# 1              []             [fr]      [565]                  [VerifiedCert]
# 2              []             [ar]      [565]                  [VerifiedCert]
# 3              []             [en]        [6]                  [VerifiedCert]
# 4              []             [en]       [32]  [VerifiedCert, Specialization]
#
#                                                 name  \
# 0  Make Your Pick-Ups Look Cool in Unity (Intro t...
# 1  Intégrer des applications dans votre Dashboard...
# 2                     كيفية استعمال التطبيق هووتسويت
# 3                                       Gamification
# 4                          Dealing With Missing Data
#
#                                    subtitleLanguages      startDate
# 0                                                 []  1598035773172
# 1                                                 []  1644614698077
# 2                                                 []  1642193091376
# 3  [ar, fr, uk, pt-PT, zh-CN, it, pt-BR, vi, de, ...  1447095621493
# 4                                               [es]  1471901099812

# %% [markdown]
# # Clean domain variable

# %%
# check if any course have more than 2 domains or no domains, drop observations
  # total of 1 observation dropped
for index, row in df.iterrows():
  num_dom = len(row["domainTypes"])
  if num_dom>2 or num_dom<1:
    print(index)
    print(num_dom)
    print(row)
    df.drop(index, inplace=True)
# Out:
# 4456
# 0
# courseType                                                 v2.ondemand
# s12nIds                                                             []
# description          Learn about the inner workings of cryptographi...
# domainTypes                                                         []
# id                                              J2MPfuJcEeWLHw5Kc9wFbw
# slug                                                           crypto2
# instructorIds                                                    [774]
# specializations                                                     []
# primaryLanguages                                                  [en]
# partnerIds                                                         [1]
# certificates                                                        []
# name                                                   Cryptography II
# subtitleLanguages                                                   []
# startDate                                                1494627509286
# Name: 4456, dtype: object

# %%
# separate domain and subdomain
## code is not optimized (currently using iterrows)
df["domain1"] = ""
df["subdomain1"] = ""
df["domain2"] = ""
df["subdomain2"] = ""
for index, row in df.iterrows():
  df.loc[index,"domain1"] = row["domainTypes"][0]["domainId"]
  df.loc[index,"subdomain1"] = row["domainTypes"][0]["subdomainId"]
  df.loc[index,"domain2"] = row["domainTypes"][-1]["domainId"]
  df.loc[index,"subdomain2"] = row["domainTypes"][-1]["subdomainId"]
  if df.loc[index,"subdomain1"]==df.loc[index,"subdomain2"]:
    df.loc[index,"subdomain2"] = ""
    if df.loc[index,"domain1"]==df.loc[index,"domain2"]:
      df.loc[index,"domain2"] = ""

# save all courses to csv
df.to_csv('courses_all.csv', index=False)
df.head()
# Out:
#     courseType                   s12nIds  \
# 0  v2.ondemand                        []
# 1  v2.ondemand                        []
# 2  v2.ondemand                        []
# 3  v2.ondemand                        []
# 4  v2.ondemand  [eYmv6d_7EeWOdA7Ea609SQ]
#
#                                          description  \
# 0  In this two-hour, project-based course, we int...
# 1  À la fin de ce projet, vous aurez toutes les c...
# 2  ينشئ العديد من الأشخاص حسابات وسائط اجتماعية م...
# 3  Gamification is the application of game elemen...
# 4  This course will cover the steps used in weigh...
#
#                                          domainTypes                      id  \
# 0  [{'domainId': 'computer-science', 'subdomainId...  NJSdGN71Eeq4CApSN3OTvQ
# 1  [{'domainId': 'business', 'subdomainId': 'mark...  DMkcgX7LEeyRTg6FtAvfBw
# 2  [{'domainId': 'business', 'subdomainId': 'mark...  YLO0oGSUEeyIUg4Qv2RsBQ
# 3  [{'subdomainId': 'design-and-product', 'domain...  69Bku0KoEeWZtA4u62x6lQ
# 4  [{'subdomainId': 'data-analysis', 'domainId': ...  0HiU7Oe4EeWTAQ4yevf_oQ
#
#                                                 slug instructorIds  \
# 0  make-pick-ups-look-cool-unity-introduction-ani...     [4730641]
# 1          integrer-applications-dashboard-hootsuite    [26958800]
# 2                  getting-started-with-hootsuite-ar    [76377122]
# 3                                       gamification      [226710]
# 4                                       missing-data     [8394050]
#
#   specializations primaryLanguages partnerIds                    certificates  \
# 0              []             [en]      [565]                  [VerifiedCert]
# 1              []             [fr]      [565]                  [VerifiedCert]
# 2              []             [ar]      [565]                  [VerifiedCert]
# 3              []             [en]        [6]                  [VerifiedCert]
# 4              []             [en]       [32]  [VerifiedCert, Specialization]
#
#                                                 name  \
# 0  Make Your Pick-Ups Look Cool in Unity (Intro t...
# 1  Intégrer des applications dans votre Dashboard...
# 2                     كيفية استعمال التطبيق هووتسويت
# 3                                       Gamification
# 4                          Dealing With Missing Data
#
#                                    subtitleLanguages      startDate  \
# 0                                                 []  1598035773172
# 1                                                 []  1644614698077
# 2                                                 []  1642193091376
# 3  [ar, fr, uk, pt-PT, zh-CN, it, pt-BR, vi, de, ...  1447095621493
# 4                                               [es]  1471901099812
#
#             domain1            subdomain1           domain2  \
# 0  computer-science  software-development
# 1          business             marketing  computer-science
# 2          business             marketing          business
# 3  computer-science    design-and-product          business
# 4      data-science         data-analysis   social-sciences
#
#                subdomain2
# 0
# 1      design-and-product
# 2       business-strategy
# 3               marketing
# 4  governance-and-society

# %% [markdown]
# # Filter domain to select DS courses

# %%
# number of courses in each domain
print(df['domain1'].value_counts())

# keep DS courses
indexes = df[ (df['domain1']!="data-science") & (df['domain2']!="data-science") ].index
df.drop(indexes, inplace=True)
df.reset_index(drop=True, inplace=True)

# save DS courses in csv
df.to_csv('courses_raw.csv', index=False)
df.head()
# Out:
#     courseType                   s12nIds  \
# 0  v2.ondemand  [eYmv6d_7EeWOdA7Ea609SQ]
# 1  v2.ondemand                        []
# 2  v2.ondemand                        []
# 3  v2.ondemand                        []
# 4  v2.ondemand  [SIs8zE87EemPhBLbT0zqZA]
#
#                                          description  \
# 0  This course will cover the steps used in weigh...
# 1  In this 1-hour long project-based course, we w...
# 2  In this 2-hour long project-based course, you ...
# 3  Machine learning (ML) is one of the fastest gr...
# 4  This course is designed to quite literally ‘ma...
#
#                                          domainTypes                      id  \
# 0  [{'subdomainId': 'data-analysis', 'domainId': ...  0HiU7Oe4EeWTAQ4yevf_oQ
# 1  [{'subdomainId': 'data-analysis', 'domainId': ...  zjIfbv3pEeqRMRJTGi3b6Q
# 2  [{'subdomainId': 'data-analysis', 'domainId': ...  LuXbfNnCEeq3nQoreMGNOQ
# 3  [{'subdomainId': 'machine-learning', 'domainId...  GHxiT9MGEemYpxKNJIfVmA
# 4  [{'subdomainId': 'data-analysis', 'domainId': ...  hwvdsk86Eem0lhKc4vCNig
#
#                                                 slug instructorIds  \
# 0                                       missing-data     [8394050]
# 1                             cluster-analysis-rcmdr    [70333041]
# 2  performing-data-aggregation-using-sql-aggregat...    [40353561]
# 3                               aws-machine-learning    [37525971]
# 4                            social-network-analysis     [1503466]
#
#   specializations primaryLanguages partnerIds                    certificates  \
# 0              []             [en]       [32]  [VerifiedCert, Specialization]
# 1              []             [en]      [565]                  [VerifiedCert]
# 2              []             [en]      [565]                  [VerifiedCert]
# 3              []             [en]      [338]                  [VerifiedCert]
# 4              []             [en]       [83]  [VerifiedCert, Specialization]
#
#                                                 name  \
# 0                          Dealing With Missing Data
# 1                       Cluster Analysis using RCmdr
# 2  Performing Data Aggregation using SQL Aggregat...
# 3          Getting Started with AWS Machine Learning
# 4                            Social Network Analysis
#
#                      subtitleLanguages      startDate       domain1  \
# 0                                 [es]  1471901099812  data-science
# 1                                   []  1601055478420  data-science
# 2                                   []  1597188408088  data-science
# 3  [ar, fr, pt-PT, it, vi, de, ru, es]  1568841469010  data-science
# 4  [ar, fr, pt-PT, it, vi, de, ru, es]  1576005639598  data-science
#
#          subdomain1                 domain2              subdomain2
# 0     data-analysis         social-sciences  governance-and-society
# 1     data-analysis
# 2     data-analysis  information-technology         data-management
# 3  machine-learning        computer-science    software-development
# 4     data-analysis         social-sciences               education

# %% [markdown]
# # Instructor and partner data

# %%
instructors = pd.DataFrame.from_dict(response_info['linked']['instructors.v1'])
instructors.rename(columns={"fullName":"instructorName","id":"instructorId"}, inplace=True)

# save instructors
instructors.to_csv('instructors_DS.csv', index=False)
print(instructors.head())

partners = pd.DataFrame.from_dict(response_info['linked']['partners.v1'])
partners.rename(columns={"name":"partnerName","id":"partnerId","shortName":"partnerShortName"}, inplace=True)

# save partners
partners.to_csv('partners_DS.csv', index=False)
print(partners.head())
# Out:
#                  instructorName instructorId
# 0                   Brian Walsh     77620729
# 1                   Emily Ellis      3259066
# 2  Harold P. Lehmann, MD, Ph.D.       678654
# 3                   Brian Casey     29515160
# 4      Vicente Hinojosa Alarcón      2636979
#                                          partnerName partnerId  \
# 0  Korea Advanced Institute of Science and Techno...       178
# 1             Check Point Software Technologies Ltd.       636
# 2                                 Capitals Coalition       994
# 3                                    DeepLearning.AI       475
# 4    The University of North Carolina at Chapel Hill        77
#
#     partnerShortName
# 0              kaist
# 1         checkpoint
# 2  capitalscoalition
# 3    deeplearning-ai
# 4                unc

# %% [markdown]
# # Scrape advanced data from course pages

# %%
from bs4 import BeautifulSoup
import re
## code is not optimized (currently using iterrows)

# initialize new columns
df["stars"] = None
df["ratings_count"] = None
df["num_enrolled"] = None
df["difficulty"] = None
df["length"] = None
df["ins_stars"] = None
df["ins_ratings_count"] = None
df["ins_learners_count"] = None
df["ins_courses_count"] = None
df["content_rating"] = None
df["content_ratings_count"] = None

# iterate through all courses
for index, row in df.iterrows():

  # set up html for scraping
  slug = row['slug']
  print(index, slug)
  url = "https://www.coursera.org/learn/" + slug
  page = requests.get(url)
  doc = BeautifulSoup(page.text, "html.parser")

  # course star rating and number of ratings
  stars = doc.find("span", attrs={"data-test":"number-star-rating"})
  if stars is not None:
    stars = float(stars.text[0:-5])
  #print("stars",stars)
  #print(type(stars))
  df.loc[index,"stars"] = stars

  ratings_count = doc.find(text=re.compile('ratings$'))
  if ratings_count is not None:
    ratings_count = int(ratings_count[0:-8].replace(',', ''))
  #print("ratings_count",ratings_count)
  #print(type(ratings_count))
  df.loc[index, "ratings_count"] = ratings_count

  # number of enrolled students
  num_enrolled = doc.find("div", attrs={"class":"_1fpiay2"})
  if num_enrolled is not None:
    num_enrolled = num_enrolled.find("span").text
    #num_enrolled = doc.find(text=re.compile('enrolled$')) #doesn't work
    num_enrolled = int(num_enrolled[0:-17].replace(',',''))
  #print("num_enrolled", num_enrolled)
  df.loc[index,"num_enrolled"] = num_enrolled

  # difficulty level
  #difficulty = doc.find("div", attrs={"class":"_16ni8zai"}, text="Level")
  difficulty = doc.find(class_="_16ni8zai",text=re.compile(' Level$'))
  if difficulty is not None:
    difficulty = difficulty.text
  #print("difficulty", difficulty)
  df.loc[index, "difficulty"] = difficulty

  # course length (hours to complete)
  length = doc.find(text=re.compile('hours to complete$'))
  if length is not None:
    length = int(re.findall(r'\d+',length)[0])
  #print("hours to complete", length)
  df.loc[index, "length"] = length

  # instructor rating and number of ratings
  ins_stars = doc.find("span", class_="avg-instructor-rating__total")
  if ins_stars is not None:
    ins_stars = float(ins_stars.text[0:-2])
  #print("ins_stars",ins_stars)
  df.loc[index,"ins_stars"] = ins_stars

  ins_ratings_count = doc.find("span", class_="avg-instructor-rating__ratings-count")
  if ins_ratings_count is not None:
    ins_ratings_count = int(ins_ratings_count.text[1:-8].replace(',',''))
  #print("ins_raings_count",ins_ratings_count)
  df.loc[index, "ins_ratings_count"] = ins_ratings_count

  # instructor learners and courses count
  ins_learners_count = doc.find("div", class_="learners-count")
  if ins_learners_count is not None:
    ins_learners_count = int(ins_learners_count.find("strong").text.replace(',',''))
  #print("ins learners count", ins_learners_count)
  df.loc[index, "ins_learners_count"] = ins_learners_count

  ins_courses_count = doc.find("div", class_="courses-count")
  if ins_courses_count is not None:
    ins_courses_count = int(ins_courses_count.find("strong").text.replace(',',''))
  #print("ins courses count", ins_courses_count)
  df.loc[index, "ins_courses_count"] = ins_courses_count

  # content rating
  content_rating = doc.find("span", class_="expertise-rating__average-rating")
  if content_rating is not None:
    content_rating = content_rating.text
  #print("content rating", content_rating)
  df.loc[index, "content_rating"] = content_rating

  content_ratings_count = doc.find("span", class_="expertise-rating p-l-1")
  if content_ratings_count is not None:
    content_ratings_count = int(content_ratings_count.find("span", text=re.compile('ratings\)$')).text[1:-9].replace(',',''))
  #print("content ratings count", content_ratings_count)
  df.loc[index, "content_ratings_count"] = content_ratings_count


df.head(10)
# Out:
# 0 missing-data
# 1 cluster-analysis-rcmdr
# 2 performing-data-aggregation-using-sql-aggregate-functions
# 3 aws-machine-learning
# 4 social-network-analysis
# 5 computer-vision-basics
# 6 analyze-data-seaborn-python
# 7 code-free-data-science
# 8 accounting-analytics
# 9 extract-transform-and-load-data
# 10 advanced-ai-techniques-for-the-supply-chain
# 11 sequence-models-tensorflow-gcp
# 12 seeking-investment-alpha-ru
# 13 googlecloud-bracketology-with-google-machine-learning-5ytsd
# 14 data-analysis-python-pandas-ar
# 15 introduction-to-virtual-networks-in-microsoft-azure
# 16 introduction-to-eda-in-r
# 17 object-detection-facebook-detectron2
# 18 visualization-for-statistical-analysis
# 19 r-programming-ar
# 20 introduction-microsoft-excel
# 21 business-valuation-approaches
# 22 text-classification-in-r
# 23 googlecloud-build-an-end-to-end-data-capture-pipeline-using-document-ai-wiisg
# 24 data-collection-analytics-project-es
# 25 app-machine-learning-spark-synapse-analytics
# 26 autoencoders-image-denoising
# 27 build-an-anomaly-detection-model-using-pycaret
# 28 data-visualization-tableau
# 29 data-analysis-tools
# 30 retinopathy-detection-using-deep-learning
# 31 image-classification-cnn-keras
# 32 python-programming
# 33 introduction-to-deep-learning-with-keras
# 34 facial-keypoint-detection
# 35 the-socio-technical-health-informatics-context
# 36 material-informatics
# 37 dataviz-design
# 38 ml-pipelines-google-cloud
# 39 ds
# 40 excel-data-analysis-ru
# 41 stability-and-capability-in-quality-improvement
# 42 supervised-machine-learning-regression
# 43 interpretable-machine-learning-applications-part-1
# 44 deep-learning-with-pytorch-gradcam
# 45 creando-bot-virtual-agents
# 46 generalized-linear-models-and-nonparametric-regression
# 47 sql-case-statements
# 48 developing-data-models-with-lookml
# 49 analisis-de-datos-con-programacion-en-r
# 50 basic-data-analysis-java-streams
# 51 introduction-clinical-data-science
# 52 launching-machine-learning-es
# 53 machine-learning
# 54 demand-analytics
# 55 information-visualization-advanced-techniques
# 56 introduction-to-data-engineering
# 57 analisis-de-datos-con-python
# 58 python-visualization
# 59 demarrer-avec-rstudio
# 60 python-data
# 61 despliegue-modelos-deep-learning-flask-heroku-postman
# 62 microsoft-azure-machine-learning-for-data-scientist
# 63 advanced-features-relational-database-table-sqlitestudio
# 64 what-is-datascience
# 65 computer-vision-microsoft-azure
# 66 series-temporales-facebook-prophet-neuralprophet
# 67 machine-learning-h2o-flow
# 68 introduction-tensorflow
# 69 text-mining-analytics
# 70 interactive-dashboards-plotly-dash
# 71 quantitative-text-analysis-and-evaluating-lexical-style-in-r
# 72 calcul-de-donnees-en-sql
# 73 sentiment-analysis-bert
# 74 doing-economics-measuring-climate-change
# 75 new-product-dev-smes
# 76 ibm-ai-workflow-machine-learning-model-deployment
# 77 googlecloud-troubleshooting-and-solving-data-join-pitfalls-ukiqz
# 78 data-visualization-manipolazione-tableau
# 79 intro-tensorflow-br
# 80 advanced-deep-learning-methods-healthcare
# 81 sas-viya-rest-api-python-r
# 82 bioconductor
# 83 tensorflow-for-cnns-learn-and-practice-cnns
# 84 interpretable-machine-learning-applications-part-4
# 85 deep-learning-with-pytorch-image-segmentation
# 86 interpreting-ml
# 87 save-load-export-keras-models
# 88 intro-tensorflow
# 89 data-insights-gcp-apply-ml-jp
# 90 explorar-data-con-spark-sql
# 91 integral-calculus-and-numerical-analysis-for-data-science
# 92 the-data-science-of-health-informatics
# 93 visualizing-filters-cnn-tensorflow
# 94 python-databases-ar
# 95 facebook-network-analysis-using-python-and-networkx
# 96 data-analysis-with-python-ar
# 97 python-data-pt
# 98 preparing-for-your-certnexus-certification-exam
# 99 python-project-for-data-engineering
# 100 linear-regression-julia
# 101 spatial-data-science
# 102 qualitative-methods
# 103 probability-theory-foundation-for-data-science
# 104 sas-programming-basics
# 105 preparing-data-for-machine-learning-models
# 106 googlecloud-how-to-build-a-bi-dashboard-using-google-data-studio-and-bigqu-cfi1a
# 107 supervised-text-classification-for-marketing-analytics
# 108 data-processing-python-collection
# 109 essentials-of-ms-word
# 110 create-an-infographic-with-infogram
# 111 compartir-datos-a-traves-del-arte-de-la-visualizacion
# 112 learning-path-data-analysis-with-pandas
# 113 sql-functions
# 114 introduction-to-machine-learning-supervised-learning
# 115 hierarchical-relational-data-analysis-using-python
# 116 robot-localization-python-particle-filter
# 117 how-use-lookup-reference-math-text-functions-excel
# 118 multi-task-models-keras
# 119 lenguaje-natural-nltk
# 120 twitter-sentiment-analysis
# 121 machine-learning-projects-ru
# 122 business-data-de
# 123 data-science-methodology
# 124 cloudera-big-data-analysis-sql-queries
# 125 big-data-language-1
# 126 python-text-mining
# 127 machine-learning-duke
# 128 object-detection-sagemaker
# 129 regression-models
# 130 tidyverse-modelling-data
# 131 database-design-postgresql
# 132 precalculus-mathematical-modelling
# 133 wrangling-data-for-data-analysts-with-python
# 134 database-design-using-sql-server-management-studio
# 135 crear-graficos-paneles-microsoft-excel
# 136 data-engineering-and-machine-learning-using-spark
# 137 life-expectancy-prediction-using-machine-learning
# 138 web-app-ml-pycaret-streamlit
# 139 citation-analysis-for-bibliometric-study
# 140 nlp-fake-news-detector
# 141 applied-data-science-for-data-analysts
# 142 imbalanced-learn-ml-datosdesequilibrados
# 143 developing-data-models-with-lookml-ja
# 144 managing-data-analysis-ru
# 145 transfer-learning-nlp-tensorflow-hub
# 146 data-augmentation-keras
# 147 machine-learning-business-professionals
# 148 nlp-modelos-y-algoritmos
# 149 visualizacion-datos-seaborn
# 150 googlecloud-using-cloud-trace-on-kubernetes-engine-1h3mh
# 151 data-insights-gcp-apply-ml
# 152 northeastern-data-privacy
# 153 tables-statistiques-pour-la-publication-dans-r
# 154 rpa-deployment-maintenance
# 155 analytics-mysql
# 156 kayfiat-aistikhdam-al-sql-mae-qawaeid-albayanat-alkabira
# 157 missing-data-es
# 158 logistic-regression-r-public-health
# 159 linear-regression-model
# 160 geodesign
# 161 aws-rekognition
# 162 business-analytics-executive-overview
# 163 image-classification-transfer-learning-keras
# 164 inferential-statistical-analysis-python
# 165 data-visualization
# 166 introduzione-data-visualization-tableau
# 167 tidyverse-data-wrangling
# 168 network-biology
# 169 solve-problems-ai-machine-learning
# 170 compare-stock-returns-google-sheets
# 171 menganalisis-data-untuk-menjawab-pertanyaan
# 172 inteligencia-artificial-powerbi
# 173 database-design-with-sql-server-management-studio
# 174 neural-networks-deep-learning-fr
# 175 data-wrangling-using-python
# 176 single-table-sql-queries
# 177 generando-modelos-automl
# 178 understanding-china-history-part-2
# 179 fundamentos-de-inteligencia-artificial-para-financas
# 180 dimensionality-reduction-autoencoder-python
# 181 build-machine-learning-image-classifier-with-python
# 182 streaming-analytics-systems-gcp-jp
# 183 what-is-datascience-ru
# 184 datasciencemathskills
# 185 googlecloud-compare-cloud-ai-platform-models-using-the-what-if-tool-to-ide-hhhxs
# 186 advanced-rdb-sql
# 187 googlecloud-build-and-execute-mysql-postgresql-and-sqlserver-to-data-catal-3jdjj
# 188 integracion-y-preparacion-de-datos
# 189 proyecto-final-de-analitica-de-datos
# 190 gis-2
# 191 fundamentos-de-la-visualizacion-de-datos-con-tableau
# 192 named-entity-recognition-lstm-keras-tensorflow
# 193 extract-text-data-java-regex
# 194 introduccion-azure-data-factory-big-data
# 195 data-analysis-reporting-sas-va
# 196 apache-spark-sql-for-data-analysts
# 197 using-date-time-functions-excel
# 198 machine-learning-pyspark-aplicado-campo-sanitario
# 199 uva-darden-market-analytics-es
# 200 fifa20-data-exploration-using-python
# 201 essential-causal-inference-for-data-science
# 202 building-custom-regional-reports-with-google-analytics
# 203 sql-data-science-ru
# 204 measuring-and-maximizing-impact-of-covid-19-contact-tracing
# 205 predictive-modeling-machine-learning
# 206 customising-models-tensorflow2
# 207 excel-analysis
# 208 googlecloud-distributed-multi-worker-tensorflow-training-on-kubernetes-bjdjq
# 209 data-visualization-science-communication
# 210 googlecloud-cloud-life-sciences-variant-transforms-tool-qosgc
# 211 microsoft-azure-machine-learning
# 212 googlecloud-vm-migration-introduction-to-stratozone-assessments-jxthj
# 213 cadeia-de-suprimentos-na-nuvem
# 214 tools-exploratory-data-analysis-business
# 215 launching-machine-learning
# 216 support-vector-machines-in-python
# 217 ibm-exploratory-data-analysis-for-machine-learning
# 218 anova-and-experimental-design
# 219 smart-analytics-machine-learning-ai-gcp
# 220 curso-completo-data-science
# 221 python-social-network-analysis-ko
# 222 exploratory-data-analysis-in-r
# 223 automl-computer-vision-microsoft-custom-vision
# 224 hypothesis-testing-in-r
# 225 tidy-messy-data-using-tidyr-in-r
# 226 calculus-through-data-and-modelling-applying-differentiation
# 227 deep-neural-network
# 228 nlp-sequence-models-fr
# 229 sql-data-science
# 230 compstatsintro
# 231 excel-intermediate-1-ar
# 232 career-guide-and-interview-prep-for-data-analyst-pc
# 233 excel-intermediate-1-fr
# 234 python-data-ru
# 235 data-analysis-with-python
# 236 excel-business-forecasting-time-series
# 237 ai2
# 238 mcmc
# 239 openvino-building-a-crossroad-ai-camera
# 240 getting-started-tensorflowjs-tensorflow-web-applications-machine-learning-python
# 241 algoritmos-de-negociacion-basados-en-machine-learning
# 242 googlecloud-bigquery-machine-learning-using-soccer-data-5olso
# 243 processing-data-with-python
# 244 amazon-echo-reviews-sentiment-nlp
# 245 intro-to-distributions-in-r
# 246 moneyball-and-beyond
# 247 publication-ready-tables-r-programming
# 248 feature-analysis-yellowbrick
# 249 use-python-java-create-gui-statistics
# 250 ai-for-medical-treatment
# 251 azure-data-factory-data-integration
# 252 googlecloud-using-bigquery-in-the-google-cloud-console-th5it
# 253 data-science-for-business-innovation
# 254 des-nombres-et-plus-en-python
# 255 prediccion-fraude-automl-pycaret
# 256 judgmental-business-forecasting-in-excel
# 257 visualizing-static-networks-r
# 258 gcp-advanced-insights-bigquery-jp
# 259 aprendizaje-automatico-con-python
# 260 linear-regression-numpy-python
# 261 data-manipulation-business-analysis-arabic
# 262 googlecloud-app-dev-storing-application-data-in-cloud-datastore-python-zqyd5
# 263 introduction-high-performance-computing
# 264 cuda-at-scale-for-the-enterprise
# 265 analyse-exploratoire-des-donnees-dans-r
# 266 covid-19-death-medical-analysis-visualization-using-plotly
# 267 crime-zone-heatmaps-python-folium
# 268 working-with-bigquery
# 269 customer-segmentation-python
# 270 preparing-data-sas-va
# 271 sourcinganalytics
# 272 machine-learning-accounting-python
# 273 fundamentals-of-cloud-computing
# 274 where-why-and-how-of-list-comprehension-in-python
# 275 data-analytics-in-sports-law-and-team-management
# 276 used-car-price-prediction-using-machine-learning-models
# 277 gcp-production-ml-systems
# 278 excel-essentials-de
# 279 interactive-word2vec
# 280 pesquisa-de-mercado-com-metodos-quantitativos
# 281 recognizing-facials-objects-amazon-rekognition
# 282 prediction-control-function-approximation
# 283 computer-vision-opencv-for-images
# 284 introduction-to-topic-modelling-in-r
# 285 intro-tensorflow-es
# 286 predicting-credit-fraud-with-r
# 287 data-mining-pipeline
# 288 dwrelational
# 289 cifar-10-image-classification
# 290 mixture-models
# 291 projeto-final-conclua-um-estudo-de-caso
# 292 business-data
# 293 healthcare-data
# 294 causal-inference-2
# 295 installation-et-configuration-de-c-avec-visual-studio-code
# 296 image-segmentation
# 297 introduction-to-regular-expressions-in-sql
# 298 googlecloud-securing-your-gke-deployments-with-binary-authorization-akovd
# 299 predict-sales-forecast-trends-in-google-sheets
# 300 play-with-graphs-using-wolfram-mathematica
# 301 cpia
# 302 data-analysis-with-r
# 303 obsidian
# 304 data-cleaning-ar
# 305 googlecloud-machine-learning-predictions-with-fhir-and-healthcare-api-vo9tu
# 306 big-data-proyecto
# 307 using-r-for-regression-and-machine-learning-in-investment
# 308 hypothesis-testing-public-health
# 309 python-data-analysis-ko
# 310 the-fundamental-of-data-driven-investment
# 311 crash-course-in-causality
# 312 otimizando-o-marketing-digital
# 313 machine-learning-investment
# 314 microsoft-excel-mqdm-l-thlyl-lbynt-bstkhdm
# 315 create-sales-dashboard-using-power-bi
# 316 googlecloud-building-a-fraud-detection-model-with-vertex-ai-automl-a68tp
# 317 recommendation-models-gcp
# 318 visualization-of-uk-accidents-using-plotly-express
# 319 data-visualization-best-practices
# 320 building-similarity-based-recommendation-system
# 321 four-rare-machine-learning-skills-all-data-scientists-need
# 322 data-driven-astronomy
# 323 autoencoders-para-reducir-la-dimensionalidad-y-el-ruido
# 324 intermediate-postgresql
# 325 time-series-data-visualization-techniques
# 326 biostatistics-2
# 327 estekhdam-gadawel-mokhtatat-pivot-excel
# 328 deploy-models-tensorflow-serving-flask
# 329 sql-window-functions-for-analytics
# 330 cloud-machine-learning-engineering-mlops-duke
# 331 3d-sars-cov-19-protein-visualization-with-biopython
# 332 global-statistics
# 333 joining-data-in-r-using-dplyr
# 334 mastering-data-analysis-with-pandas-learning-path-part-3
# 335 machine-learning-projects-ko
# 336 python-for-data-visualization-seaborn
# 337 ajukan-pertanyaan-untuk-mengambil-keputusan-berdasarkan-data
# 338 gcp-big-data-ml-fundamentals-fr
# 339 business-analytics-decision-making-ko
# 340 reconhecimento-facial-objetos-aws-amazon-rekognition
# 341 mlm
# 342 proyek-akhir-menyelesaikan-sebuah-studi-kasus
# 343 intelligence-artificielle-pour-gamers
# 344 getting-started-with-tensor-flow2
# 345 convolutional-neural-networks-fr
# 346 quantitative-text-analysis-and-scaling-in-r
# 347 portfolio-diversification-correlation-matrix
# 348 web-data
# 349 wharton-operations-analytics
# 350 googlecloud-cloud-filestore-qwik-start-6b89l
# 351 measuring-stock-liquidity-ru
# 352 business-analytics-r
# 353 build-dashboards-power-bi
# 354 bn-nmwdhj-t-lm-lal-bstkhdm-power-bi-luluk
# 355 medical-insurance-premium-prediction-with-machine-learning
# 356 data-analysis-capstone
# 357 smart-analytics-machine-learning-ai-gcp-br
# 358 data-analysis-project-pwc
# 359 analticas-de-datos-con-pandas
# 360 excel-essentials-fr
# 361 classification-of-covid19-using-chest-xray-images-in-keras
# 362 googlecloud-big-data-analysis-to-a-slide-presentation-87ijx
# 363 analyzing-and-visualizing-data-in-looker-ja
# 364 object-localization-tensorflow
# 365 predict-ideal-diamonds-with-a-random-forest-using-r
# 366 classify-radio-signals-space-keras-cnn
# 367 art-science-ml-es
# 368 crash-couse-in-gnuplot
# 369 statistics-for-data-science-python
# 370 time-series-survival-analysis
# 371 chatbot-rasa-python
# 372 deep-learning-with-pytorch-siamese-network
# 373 serverless-data-processing-with-dataflow-operations-es
# 374 convolutional-neural-networks-tensorflow
# 375 exploratory-data-analysis
# 376 intermediate-rdb-sql
# 377 estatistica-nao-parametrica
# 378 advanced-reports-sas-va
# 379 data-analysis-visualization-foundations-assessment
# 380 python-data-processing
# 381 sas-programming-certification-review
# 382 master-data-analysis-with-pandas-learning-path-1-enhanced
# 383 introduction-to-dplyr
# 384 measuring-disease-epidemiology
# 385 introducao-big-data
# 386 regression-and-classification
# 387 python-data-es
# 388 getting-started-rstudio
# 389 how-visualize-research-data-tableau
# 390 finance-for-the-non-finance-professionals
# 391 generate-report-libreoffice-base
# 392 machine-learning-for-customer-segmentation
# 393 linear-regression-business-statistics
# 394 simulation-call-centre-operations
# 395 creando-aplicaciones-shiny
# 396 data-intensive-applications
# 397 jhu-getting-started-data-viz-r
# 398 data-products
# 399 iiot-google-cloud-platform
# 400 predicting-salaries-decision-trees
# 401 importance-of-listening
# 402 interactive-kpi-tableau-dashboard
# 403 completa-un-caso-practico
# 404 data-science-fundamentals-for-data-analysts
# 405 introduccion-a-pandas-para-data-science
# 406 googlecloud-predict-taxi-fare-with-a-bigquery-ml-forecasting-model-0ucjz
# 407 proceso-de-datos-sucios-a-datos-limpios
# 408 googlecloud-tracking-cryptocurrency-exchange-trades-with-google-cloud-plat-eneyt
# 409 compartilhar-os-dados-com-a-arte-da-visualizacao
# 410 quantitative-text-analysis-and-textual-similarity-in-r
# 411 python-data-analysis
# 412 recommender-systems-introduction
# 413 analytics-business-metrics-ar
# 414 data-mining-methods
# 415 machine-learning-trading-finance
# 416 data-warehousing-with-microsoft-azure-synapse-analytics
# 417 pca-machine-learning
# 418 serverless-machine-learning-gcp-br
# 419 clinical-research-biostatistics-wolfram
# 420 bayesian-statistics-time-series-analysis
# 421 collaborative-filtering
# 422 uva-darden-market-analytics-fr
# 423 understanding-china-history-part-1
# 424 gcp-big-data-ml-fundamentals-es
# 425 data-manipulation-with-dplyr-in-r
# 426 regular-expressions-in-python
# 427 mlops-fundamentals
# 428 managing-data-analysis
# 429 gcp-big-data-ml-fundamentals
# 430 machine-learning-asset-management-alternative-data
# 431 diabetes-prediction-with-pyspark-mllib
# 432 communicating-business-analytics-results
# 433 analytics-information-capstone
# 434 introduction-al-analisis-de-datos
# 435 google-data-studio-rapport
# 436 transiao-energtica-e-ecologica-em-paises-do-sul
# 437 managing-describing-analyzing-data
# 438 ethical-frameworks-action
# 439 design-thinking-predictive-analytics-data-products
# 440 ml-classification
# 441 genome-analysis-hierarchical-clustering
# 442 healthcare-data-models
# 443 python-pandas-merge-sort-filter
# 444 genomic-tools
# 445 como-usar-funciones-mtodos-y-bucles-en-python-desde-cero
# 446 ml-safety-stock
# 447 custom-models-layers-loss-functions-with-tensorflow
# 448 the-total-data-quality-framework
# 449 open-source-tools-for-data-science
# 450 linear-algebra-machine-learning
# 451 data-analyze-visualize
# 452 d3-basics
# 453 analytical-solutions-common-healthcare-problems
# 454 vision-computacional-sagemaker
# 455 manipulating-data-with-sql
# 456 data-calculations-microsoft-excel
# 457 data-visualization-capstone
# 458 attention-models-in-nlp
# 459 ai-algorithm-limitations
# 460 excel-data-analysis-de
# 461 crea-tu-primer-juego-de-adivinanza-con-python
# 462 transformer-donnees-avec-r
# 463 googlecloud-integrating-machine-learning-apis-sio9h
# 464 nursing-informatics-leaders
# 465 formula-preguntas-para-tomar-decisiones-basadas-en-datos
# 466 introduction-image-processing
# 467 googlecloud-creating-a-data-transformation-pipeline-with-cloud-dataprep-dymxo
# 468 googlecloud-bigquery-soccer-data-analysis-ai3rr
# 469 build-a-real-time-stock-market-dashboard-using-power-bi
# 470 smart-analytics-machine-learning-ai-gcp-jp
# 471 mongodb-aggregation-framework
# 472 digital-analytics
# 473 excel-advanced-ru
# 474 deep-learning-with-pytorch--object-localization
# 475 predict-poison-mushrooms-using-random-forest
# 476 data-visualization-using-plotnine
# 477 regression-modeling-sas
# 478 googlecloud-exploring-your-ecommerce-dataset-with-sql-in-google-bigquery-dwh3o
# 479 use-power-bi-for-financial-data-analysis-project
# 480 fundamentos-de-ia-aplicados-ao-crm
# 481 computational-neuroscience
# 482 introduccion-a-las-bases-relacionales-sql
# 483 nlp-english-to-french-translation
# 484 data-visualization-using-bokeh
# 485 predicciones-amazon-forecast
# 486 intro-to-r-basic-syntax
# 487 gcp-creating-bigquery-datasets-visualizing-insights-jp
# 488 introduction-statistics-data-analysis-public-health
# 489 art-science-ml
# 490 networkx
# 491 introduction-to-designing-data-lakes-in-aws
# 492 end-to-end-ml-tensorflow-gcp
# 493 powerpoint-presentations
# 494 advanced-computer-vision-with-tensorflow
# 495 googlecloud-create-and-test-a-document-ai-processor-syrzz
# 496 launching-machine-learning-leadership
# 497 machine-learning-regression-yellowbrick
# 498 wharton-ai-strategy-governance
# 499 precalculus-periodic-functions
# 500 python-istruzioni-per-uso
# 501 marketing-analytics
# 502 spark-sql
# 503 googlecloud-setting-up-cost-control-with-quota-ppomk
# 504 support-vector-machine-classification-python
# 505 follow-machine-learning-workflow
# 506 portafolios-inversiones-en-mercado-de-capitales
# 507 build-better-generative-adversarial-networks-gans
# 508 basic-recommender-systems
# 509 tidyverse-importing-data
# 510 pneumonia-classification-using-pytorch
# 511 pesquisa-de-mercado-com-metodos-qualitativos
# 512 manipulate-data-using-power-bi-desktop
# 513 learning-sas-history-and-sas-studio
# 514 clustering-world-happiness-report
# 515 predictive-analytics-data-mining
# 516 handling-imbalanced-data-classification-problems
# 517 formatting-text-in-ms-word
# 518 neural-networks-deep-learning-ko
# 519 supervised-machine-learning-classification
# 520 linear-regression
# 521 create-buy-signal-filter-using-r-quantmod-package
# 522 googlecloud-block-one-getting-started-with-the-eosio-blockchain-2rsmf
# 523 economics-of-ai
# 524 probabilistic-graphical-models-2-inference
# 525 convolutional-neural-networks-ru
# 526 the-power-of-machine-learning
# 527 financas-orientada-a-dados
# 528 googlecloud-deploying-an-open-source-cassandra-tm-database-using-the-gcp-mfzn3
# 529 sql-for-data-science-de
# 530 nlp-sequence-models-ar
# 531 decision-tree-classifier-for-beginners-in-r
# 532 despliegue-de-modelos-ia-iot-edge-con-onnx
# 533 query-database-table-sql-libreoffice-base
# 534 mastering-data-analysis-with-pandas-learning-path-part-4
# 535 python-para-data-science-y-ai
# 536 r-programmierung-zur-datenanalyse
# 537 transformacao-digital-marketing-na-era-dos-dados
# 538 dwdesign
# 539 analyze-data-plotly-python
# 540 agrgation-de-donnes-avec-des-requtes-sql
# 541 healthcare-data-quality-governance
# 542 get-started-tableau
# 543 machine-learning-for-kyphosis-disease-classification
# 544 dashboarding-deployment
# 545 googlecloud-using-prometheus-for-monitoring-on-google-cloud-qwik-start-jzu9n
# 546 tanseq-el-mokhasas-w-el-sharty-fi-microsoft-excel
# 547 wharton-decision-making-scenarios
# 548 business-intelligence-con-tableau
# 549 googlecloud-a-tour-of-cloud-iot-core-g2kr8
# 550 nlp-sequence-models-ru
# 551 visualizing-citibike-trips-tableau
# 552 statistics-machine-learning-investment
# 553 daten-bereinigen
# 554 googlecloud-migrating-an-application-and-data-from-apache-cassandra-tm-to-tnrgn
# 555 deploy-predictive-ml-model-ibm-cloud
# 556 cdss5-capstoneassignment
# 557 google-data-analytics-finale-eine-fallstudie-anfertigen
# 558 what-is-datascience-ko
# 559 linear-regression-r-public-health
# 560 python-for-applied-data-science-ai-ar
# 561 healthcare-data-literacy
# 562 sql-para-ciencia-de-datos
# 563 accounting-data-analytics-capstone
# 564 googlecloud-collect-metrics-from-exporters-using-the-managed-service-for-zpdra
# 565 ibm-rapid-prototyping-watson-studio-autoai
# 566 analisar-os-dados-para-responder-as-perguntas
# 567 facial-key-point-detection
# 568 computer-vision-with-embedded-machine-learning
# 569 einfuehrung-in-die-datenvisualisierung-mit-microsoft-excel
# 570 optimization-for-decision-making
# 571 data-wrangling-analysis-abtesting
# 572 create-audio-transcripts-with-amazon-transcribe
# 573 principal-component-analysis-numpy
# 574 impacto-datos-masivos
# 575 machine-learning-data-mining-con-r
# 576 meaningful-predictive-modeling
# 577 streaming-analytics-systems-gcp
# 578 scikit-learn-k-means-clustering-image-compression
# 579 google-data-analytics-capstone
# 580 visualizacion-de-datos-con-python
# 581 hypothesis-testing-confidence-intervals
# 582 estadistica-aplicada-negocios
# 583 google-machine-learning
# 584 dataviz-visual-analytics
# 585 quantitative-text-analysis-and-measures-of-readability-in-r
# 586 data-science-methodology-ru
# 587 automated-machine-learning-powerbi
# 588 advanced-models-smartpls
# 589 advanced-sas-programming-techniques
# 590 convolutional-neural-networks-ar
# 591 introduccion-al-aprendizaje-profundo
# 592 gcp-advanced-insights-bigquery
# 593 business-intelligence-data-warehousing
# 594 automatic-machine-learning-h2o-automl-python
# 595 nazrat-eamat-ealaa-tahlilat-aleumala-biastikhdam-barnamaj-excel
# 596 mri-fundamentals
# 597 ibm-unsupervised-machine-learning
# 598 gcp-big-data-ml-fundamentals-jp
# 599 polynomials-roots
# 600 intermediate-programming-capstone
# 601 googlecloud-streaming-iot-core-data-to-dataprep-scqyb
# 602 developing-ai-applications-azure
# 603 curso-completo-power-bi-service
# 604 basic-statistics-python-anova
# 605 data-science-k-means-clustering-python
# 606 reverse-and-complement-nucleic-acid-sequences-using-r
# 607 python-databases-ru
# 608 googlecloud-using-custom-fields-in-looker-explores-nrr2j
# 609 classification-vector-spaces-in-nlp
# 610 scikit-learn-logistic-regression-sentiment-analysis
# 611 promote-ethical-data-driven-technologies
# 612 sas-programming-advanced
# 613 wharton-introduction-spreadsheets-models
# 614 business-statistics-analysis-capstone
# 615 ethical-data-driven-technology-leader
# 616 machine-learning-introduction-for-everyone
# 617 siamese-network-triplet-loss-keras
# 618 ciclo-completo-del-desarrollo-de-un-proyecto-de-data-science
# 619 matrix-methods
# 620 fashion-classification-with-deep-learning
# 621 rstudio-six-sigma-control-charts
# 622 google-classroom-arabic
# 623 covid19-data-analysis-using-python
# 624 resume-and-cover-letter-arabic
# 625 statistiques-descriptives-et-inferentielles-en-r
# 626 visualizacion-de-datos-y-tableros-con-excel-y-cognos
# 627 modelos-sagemaker
# 628 unsupervised-algorithms-in-machine-learning
# 629 get-started-with-r-markdown
# 630 dna-sequencing
# 631 data-driven-process-improvement
# 632 improving-statistical-questions
# 633 clinical-natural-language-processing
# 634 logistic-regression-numpy-python
# 635 extraire-des-donnes-de-texte-avec-python-et-regex
# 636 beginners-guide-to-aws-identity-and-access-management
# 637 contabilidad-como-herramienta-gerencial
# 638 data-analysis-with-python-ru
# 639 creacion-chatbot-azure
# 640 measurement-turning-concepts-data
# 641 smartpls-advanced-regression
# 642 getting-started-data-analytics-aws
# 643 python-for-applied-data-science-ai-ru
# 644 serverless-data-processing-with-dataflow-foundations-es
# 645 titanic-survival-prediction-using-machine-learning
# 646 reverse-and-complement-nucleic-acid-sequences-using-python
# 647 applied-data-science-capstone-ru
# 648 data-collection-framework
# 649 chatbot-composer
# 650 geospatial-covid19-python
# 651 chances-probability-uncertainty-statistics
# 652 excel-data-analysis
# 653 build-basic-generative-adversarial-networks-gans
# 654 streaming-analytics-systems-gcp-br
# 655 deep-learning-with-pytorch-generative-adversarial-network
# 656 visualizacion-avanzada-datos-python
# 657 practicing-sas-programming-certification
# 658 ai-data-bias
# 659 nlp-with-pycaret
# 660 gis-1
# 661 exploratory-data-analysis-python
# 662 creating-database-tables-with-sql
# 663 sas-statistics
# 664 big-data-graph-analytics
# 665 takid-sihat-albayanat-faa-sql
# 666 gis-data-acquisition-map-design
# 667 convolution-text-classification-keras
# 668 clinical-data-models-and-data-quality-assessments
# 669 tracking-objects-video-particle-filter
# 670 data-lakes-azure
# 671 generate-invoice-libreoffice-base
# 672 geospatial-keplergl-jupyter
# 673 regression-automatic-differentiation-tensorflow
# 674 deep-learning-with-pytorch-neural-style-transfer
# 675 feature-engineering-matlab
# 676 creating-visualizations-and-reports-using-power-bi
# 677 tensorflow-sequences-time-series-and-prediction
# 678 hypothesis-testing-python-excel
# 679 data-science-with-r-capstone-project
# 680 kanban-control-simulation
# 681 data-results
# 682 stanford-statistics
# 683 choisir-la-meilleure-methode-pour-illustrer-les-donnees
# 684 basic-desc-r-cmdr
# 685 foundations-big-data-analysis-sql
# 686 data-preparation
# 687 codio-data-analysis-in-r-with-rstudio-and-tidyverse
# 688 datasci-capstone
# 689 algebra-and-differential-calculus-for-data-science
# 690 deep-learning-for-real-estate-price-prediction
# 691 breast-cancer-prediction-using-machine-learning
# 692 ai-for-medical-prognosis
# 693 building-resilient-streaming-systems-gcp-br
# 694 cdss2
# 695 validate-data-sql-mysql-workbench
# 696 applied-data-science-capstone-ar
# 697 introducao-a-base-de-dados-relacionais-sql
# 698 analyze-stock-data-using-r-quantmod
# 699 data-science-course-de
# 700 googlecloud-cloud-spanner-create-a-gaming-leaderboard-with-c-yovbf
# 701 building-deep-learning-models-with-tensorflow
# 702 jhu-advanced-data-visualization-r
# 703 hr-analytics-build-hr-dashboard-using-power-bi
# 704 dplyr
# 705 mbse
# 706 herramientas-para-la-ciencia-de-datos
# 707 deep-neural-network-ru
# 708 intro-practical-deep-learning
# 709 modelos-predictivos-con-aprendizaje-automatico
# 710 talend-di-dev-cert-prep
# 711 tweet-emotion-tensorflow
# 712 microsoft-dp-203-practice-exam
# 713 fundamentos-de-inteligencia-artifical-em-marketing
# 714 intro-business-analytics
# 715 neural-networks-deep-learning-ar
# 716 google-ads-arabic
# 717 analitica-procesos-optimizacion-desde-datos
# 718 digital-thread-implementation
# 719 daten-uber-visualisierungen-teilen
# 720 nlp-sequence-models-ko
# 721 big-data-project
# 722 enjoyable-econometrics
# 723 overview-of-data-visualization-in-microsoft-excel
# 724 genome-analysis-z-curve
# 725 desplegando-modelos-ml-pycaret-azure
# 726 demand-prediction-using-time-series
# 727 statistical-inference
# 728 sagemaker-tensorflow
# 729 introduction-a-l-html
# 730 recommeder-systems-capstone
# 731 data-visualization-python-ar
# 732 statistics-data-science
# 733 data-viz-shiny-dashboards
# 734 googlecloud-debugging-applications-for-site-reliability-engineers-xbby8
# 735 machine-learning-for-supply-chain-fundamentals
# 736 introduction-to-ai
# 737 googlecloud-detect-labels-faces-and-landmarks-in-images-with-the-cloud-vis-tsdqu
# 738 statistical-data-visualization-seaborn-ust
# 739 erste-schritte-mit-r-markdown
# 740 googlecloud-classify-images-of-cats-and-dogs-using-transfer-learning-6qgew
# 741 digital-thread-components
# 742 googlecloud-google-cloud-pub-sub-qwik-start-command-line-nnzjc
# 743 introduction-to-node-red
# 744 covid-19-cases-forecasting-using-fbp
# 745 language-classification
# 746 power-sample-size
# 747 explore-insights-in-text-analysis-using-azure-text-analytics
# 748 functional-mri-2
# 749 ibm-ai-workflow-business-priorities-data-ingestion
# 750 investment-risk-management-arabic
# 751 how-use-custom-conditional-formatting-excel
# 752 data-analytics-accountancy-1
# 753 introduction-to-python
# 754 cdss4
# 755 create-csharp-app-process-mongodb-data
# 756 statistics-for-marketing
# 757 train-machine-learning-models
# 758 dataviz-grammaire-des-graphiques-avec-python
# 759 power-bi-iawhat-bayanat-mabieat-biaistikhdam-barnamaj
# 760 transforming-data-in-r
# 761 fundamentals-of-reinforcement-learning
# 762 explain-pandas-load-and-export-data
# 763 statistical-forecasting-techniques-in-google-sheets
# 764 transfer-learning-food-classification
# 765 facial-expression-recognition-keras
# 766 google-machine-learning-fr
# 767 series-temporales-con-pycaret-python
# 768 googlecloud-predict-housing-prices-with-tensorflow-and-ai-platform-wbgwf
# 769 managing-data-analysis-de
# 770 building-recommendation-system-using-mxnet-aws-sagemaker
# 771 image-compression-generation-vae
# 772 executive-data-science-capstone
# 773 using-ggplot
# 774 using-microsoft-azure-ml-for-kaggle
# 775 data-analytics-business-capstone
# 776 gestao-de-dados-cientificos
# 777 wharton-ai-fundamentals-non-data-scientists
# 778 cloud-storage-big-data-analysis-sql
# 779 rstudio-six-sigma-hypothesis-testing
# 780 getting-started-imagej
# 781 machine-learning-interpretable-lime
# 782 ml-foundations-ko
# 783 calculus-through-data-and-modelling-techniques-of-integration
# 784 deep-dive-tensorflow-activation-functions
# 785 data-visualization-with-python
# 786 panel-data-analysis-with-r
# 787 tri-et-filtrage-dans-sql
# 788 machine-learning-projects
# 789 process-data-with-microsoft-azure-synapse-link-for-cosmo-db
# 790 analytics-capstone
# 791 build-your-first-search-engine-using-aws-kendra
# 792 probabilistic-models-in-nlp
# 793 image-understanding-tensorflow-gcp
# 794 rpa-development-testing
# 795 multiple-regression-analysis-public-health
# 796 introduction-to-predictive-modeling
# 797 aerial-image-segmentation-with-pytorch
# 798 statistical-inference-for-estimation-in-data-science
# 799 custom-attribution-modeling-with-google-analytics
# 800 bayesian
# 801 memproses-data-dari-kotor-ke-bersih
# 802 automating-image-processing
# 803 googlecloud-creating-dynamic-sql-derived-tables-with-lookml-and-liquid-dcbpp
# 804 the-pytorch-basics-you-need-to-start-your-ml-projects
# 805 scikit-learn-multiple-linear-regression
# 806 complete-reinforcement-learning-system
# 807 istkhdam-moaadalat-wzaeef-baseeta-fi-microsoft-excel
# 808 streaming-analytics-systems-gcp-es
# 809 machinedeep-learning-for-mining-quality-prediction-enhanced
# 810 clinical-predictive-modeling
# 811 machine-teaching-ai
# 812 developing-pipelines-on-dataflow-es
# 813 estadisticas-para-la-ciencia-de-datos-con-python
# 814 data-manipulation
# 815 calculus-through-data-and-modelling-differentiation-rules
# 816 use-python-non-data-role
# 817 performing-data-definition-and-manipulation-in-sql
# 818 import-data-into-r
# 819 net-promoter-score-nps-sentiment-analysis-miro
# 820 data-storage-microsoft-azure-developers
# 821 text-generation-markov-chains-python
# 822 introduction-to-microsoft-azure-synapse-analytics
# 823 linux-and-bash-for-data-engineering-duke
# 824 pycaret-regression
# 825 data-visualization-using-plotly
# 826 ml-bigdata-pyspark-retencion-clientes
# 827 address-business-issues-with-data-science
# 828 simulation-drum-buffer-rope
# 829 wharton-people-analytics
# 830 aspectos-basicos-datos-datos-en-todas-partes
# 831 deep-learning-reinforcement-learning
# 832 redesecologicas
# 833 covid-19-mrna-vaccine-degradation-prediction
# 834 deploy-video-indexing-application-using-azure-video-analyzer
# 835 tableau-public-interactive-graph
# 836 applied-calculus-with-python
# 837 styles-html-css
# 838 bot-luis
# 839 image-segmentation-python-unsupervised-learning
# 840 sql-date-time-functions
# 841 working-big-data
# 842 ai-for-drug-discovery
# 843 create-geovisualizations-tableau
# 844 googlecloud-data-studio-qwik-start-bc935
# 845 using-tensorflow-image-style-transfer
# 846 ibm-ai-workflow-feature-engineering-bias-detection
# 847 join-tables-sql-query-libreoffice-base
# 848 curso-completo-spark-databricks
# 849 investment-risk-management
# 850 deep-learning-with-pytorch-build-an-autoencoder
# 851 where-why-and-how-of-lambda-functions-in-python
# 852 ferramentas-para-ciencia-de-dados-introducao-ao-r
# 853 fundamentals-of-data-analysis
# 854 aprenda-ia-con-ibm-watson
# 855 regresion-logistica-con-numpy-python
# 856 grab-data-fast-with-vertical-and-horizontal-lookup-in-google-sheets
# 857 analiza--tu-mercado-con-python
# 858 build-decision-trees-svms-neural-networks
# 859 data-analytics-business
# 860 decision-tree-random-forest-classification-julia
# 861 instagram-fake-profile-detector
# 862 introduction-to-relational-databases
# 863 codio-data-analysis-in-python-with-pandas-and-matplotlib-in-spyder
# 864 machine-learning-techniques
# 865 hadoop
# 866 excel-aplicado-negocios-avanzado
# 867 googlecloud-introduction-to-cloud-dataproc-hadoop-and-spark-on-google-clou-j3jfl
# 868 googlecloud-identify-damaged-car-parts-with-vertex-automl-vision-bugvm
# 869 iinsha-jadawil-qaeidat-albayanat-sql
# 870 learning-sas-creating-formats-and-labels
# 871 big-data-introduction
# 872 predictive-modeling-model-fitting-regression-analysis
# 873 digital-footprint
# 874 amazon-fraud-detector
# 875 googlecloud-using-cloud-error-reporting-to-remediate-workload-issues-on-gk-kuthl
# 876 topic-modeling-using-pycaret
# 877 como-importar-datos-y-crear-visualizaciones-en-python
# 878 capstone-connected-planning-for-business-transformation
# 879 rstudio-six-sigma-process-capability
# 880 advanced-data-science-capstone
# 881 python-databases
# 882 deploying-a-pytorch-computer-vision-model-api-on-heroku
# 883 create-big-number-kpi-dashboard-tableau-public
# 884 applied-data-science-capstone
# 885 medical-diagnosis-support-vector-machines
# 886 build-a-business-architecture-using-aws-organization
# 887 sas-predictive-modeling-using-logistic-regression
# 888 launching-machine-learning-fr
# 889 machine-learning-sas
# 890 automl
# 891 tensorflow-regularization-avoid-overfitting
# 892 intelligent-machining
# 893 population-health-predictive-analytics
# 894 ask-questions-make-decisions
# 895 sentimental-anlysis-on-covid-19-tweets-using-python
# 896 quantifying-relationships-regression-models
# 897 python-representation
# 898 googlecloud-bigquery-soccer-data-analytical-insight-yrrml
# 899 fragen-fur-eine-datengesteuerte-entscheidungsfindung-stellen
# 900 googlecloud-using-bigquery-with-c-ydycl
# 901 microsoft-ai-900-exam-prep
# 902 conceptos-basicos-de-excel-para-el-analisis-de-datos
# 903 humanidades-digitales
# 904 guided-tour-machine-learning-finance
# 905 simple-nearest-neighbors-regression-and-classification
# 906 google-sheets-plots-arabic
# 907 career-guide-and-interview-prep-for-data-science-pc
# 908 googlecloud-the-apps-script-cli-clasp-668tw
# 909 modern-regression-analysis-in-r
# 910 eda-text-r-quanteda
# 911 intro-reproducibility-cancer-informatics
# 912 applying-data-analytics-business-in-finance
# 913 deep-learning-fundamentals-logistic-regression
# 914 indices-de-base-de-donnees-expliques
# 915 python-for-data-visualization-ar
# 916 advanced-machine-learning-signal-processing
# 917 hyperparameter-tuning
# 918 scikit-learn-simple-linear-regression
# 919 googlecloud-vertex-pipelines-qwik-start-cqsni
# 920 classify-dog-breeds
# 921 deep-neural-networks-with-pytorch
# 922 digital-humanities
# 923 businessintelligence
# 924 exploratory-vs-confirmatory-data-analysis-using-python
# 925 meaningful-marketing-insights
# 926 advanced-manufacturing-process-analysis
# 927 explainable-machine-learning-lime-h2o
# 928 measuring-total-data-quality
# 929 matrix-factorization
# 930 probabilistic-deep-learning-with-tensorflow2
# 931 automl-autokeras-classification
# 932 azure-data-engineer-databricks-data-factory
# 933 cnns-and-rnns
# 934 data-science-and-scikit-learn-in-python
# 935 telecom-customer-churn-prediction
# 936 financial-risk-management-with-r
# 937 probabilistic-graphical-models-3-learning
# 938 big-data-visualizacion-datos
# 939 interactive-dashboards-streamlit-python
# 940 build-bot-python-basic-file-interface-chores
# 941 googlecloud-troubleshooting-common-sql-errors-with-bigquery-q3baf
# 942 creating-budget-microsoft-excel
# 943 preparar-os-dados-para-exploracao
# 944 r-programming-environment
# 945 tensorflow-tensorrt
# 946 generative-adversarial-networks-keras
# 947 googlecloud-mapping-the-nyc-subway-vpunt
# 948 master-data-visualization-tableau
# 949 getting-started-tidyverse
# 950 predictive-modelling-azure-machine-learning-studio
# 951 employee-attrition-prediction
# 952 exploratory-data-analysis-ar
# 953 analyser-donnees-python
# 954 process-data
# 955 recommender-metrics
# 956 advanced-topics-in-ms-word
# 957 curso-completo-power-bi
# 958 formatting-pages-in-ms-word
# 959 leveraging-unstructured-data-dataproc-gcp-br
# 960 cartographie
# 961 deep-learning-business
# 962 machine-learning-under-the-hood
# 963 introduction-cs-type-system
# 964 sig-1
# 965 network-path-text-analyses-sas-va
# 966 rh-dados-e-inteligencia-artificial
# 967 finding-sorting-filtering-data-microsoft-excel
# 968 database-creation-and-modeling-using-mysqlworkbench
# 969 wharton-ai-applications-marketing-finance
# 970 analticas-y-mtricas-de-marketing
# 971 conditional-formatting-tables-charts-microsoft-excel
# 972 ethical-issues-data-science
# 973 mastering-sql-joins
# 974 googlecloud-connect-an-app-to-a-cloud-sql-for-postgresql-instance-mhiqu
# 975 ai-with-ibm-watson
# 976 mcmc-bayesian-statistics
# 977 relational-database
# 978 charts-dashboard-google-sheets
# 979 strategic-business-analytics-capstone
# 980 power-bi-desktop
# 981 build-clustering-model-using-pycaret
# 982 statistical-analysis-using-python-numpy
# 983 neurohacking
# 984 conducting-exploratory-data-analysis
# 985 new-product-dev-sme-arabic
# 986 python-databases-pt
# 987 mastering-data-analysis-with-pandas-learning-path-part-2
# 988 introduction-to-sql-window-functions
# 989 mlops-databricks
# 990 fundamentals-of-big-data
# 991 gcp-creating-bigquery-datasets-visualizing-insights
# 992 accounting-data-analytics-python
# 993 training-others-nursing-informatics
# 994 data-scientists-tools-ar
# 995 developing-pipelines-on-dataflow-pt
# 996 logistic-regression-classification-julia
# 997 introduction-data-analysis-microsoft-excel
# 998 analytics-data-decisions
# 999 business-intelligence-tools
# 1000 malaria-parasite-detection-ensemble-learning-keras
# 1001 power-bi-business-intelligence
# 1002 advanced-sql-retrieval-queries-in-sqlitestudio
# 1003 hipython
# 1004 interpretable-machine-learning-applications-part-2
# 1005 big-data-procesamiento-analisis
# 1006 googlecloud-predict-visitor-purchases-with-a-classification-model-in-bqml-gsu1k
# 1007 advanced-portfolio-construction-python
# 1008 relational-database-design
# 1009 summary-statistics
# 1010 clasificacion-tensorflow
# 1011 advanced-excel
# 1012 predictive-modeling-analytics
# 1013 fitting-statistical-models-data-python
# 1014 basic-relational-databases-sql
# 1015 visualization-for-data-journalism
# 1016 cyber-security-manufacturing
# 1017 using-data-geographic-mapping-sas-va
# 1018 ml-regression
# 1019 serverless-data-processing-with-dataflow-operations
# 1020 getting-started-with-tensor-flow2-ko
# 1021 machine-learning-modeling-pipelines-in-production
# 1022 machine-learning-with-python
# 1023 python-databases-es
# 1024 wharton-risk-models
# 1025 editing-text-in-ms-word
# 1026 design-strategies-for-maximizing-total-data-quality
# 1027 real-life-data-science
# 1028 network-analysis-for-marketing-analytics
# 1029 data-warehouse-bi-building
# 1030 portfolio-optimization-markowitz-model
# 1031 nettoyer-donnees-python
# 1032 analysis-of-variance-anova-in-google-sheets
# 1033 feature-engineering-es
# 1034 practical-machine-learning
# 1035 systems-network-kumu
# 1036 launching-machine-learning-jp
# 1037 google-machine-learning-es
# 1038 deep-neural-network-ko
# 1039 rstudio-six-sigma-basic-statistics
# 1040 measurement-systems-analysis
# 1041 aws-improve-python-code-amazon-codeguru
# 1042 keras-tuner
# 1043 investment-risk-management-ru
# 1044 simple-regression-analysis-public-health
# 1045 computational-social-science-methods
# 1046 sistemas-difusos
# 1047 ml-powerbi-ventas-retail
# 1048 primeros-pasos-sql
# 1049 crash-course-on-interactive-data-visualization-with-plotly
# 1050 analisis-data-dengan-pemrograman-r
# 1051 cdss3
# 1052 serverless-machine-learning-gcp-de
# 1053 tirer-parti-des-listes-pour-un-code-python-plus-simple
# 1054 googlecloud-cloud-operations-for-gke-hhhly
# 1055 neural-network-tensorflow
# 1056 convolutional-neural-networks
# 1057 nazaruh-eamatan-ean-albayanat-almusawarat-biastikhdam-tableau
# 1058 scatter-plot-data-scientists-big-data-analysts-visuals
# 1059 analyze-text-data-yellowbrick
# 1060 introduction-to-embedded-machine-learning
# 1061 precalculus-relations-functions
# 1062 time-series-analysis-arima-with-r
# 1063 automated-reasoning-sat
# 1064 excel-intermediate-1
# 1065 python-per-la-data-science
# 1066 r-programming
# 1067 introduction-to-data-analytics
# 1068 data-analytics-introduction
# 1069 responsible-data-analysis
# 1070 datavisualization
# 1071 tensorflow-beginner-predicting-house-prices-regression
# 1072 data-analytics-power-bi
# 1073 marketing-e-o-consumidor-no-ambiente-digital
# 1074 analytics-tableau
# 1075 big-data-ai-ethics
# 1076 automl-pycaret-tpot
# 1077 data-science-ethics
# 1078 experimentation
# 1079 uva-darden-market-analytics
# 1080 computational-phenotyping
# 1081 graduate-admission-prediction-with-pyspark-ml
# 1082 affectation-de-variable-en-python
# 1083 bayesian-statistics
# 1084 machine-learning-algorithms-r-business-analytics
# 1085 build-classification-model-using-pycaret
# 1086 googlecloud-cloud-composer-qwik-start-console-9tte1
# 1087 analisis-sentimientos-azure
# 1088 deploying-machine-learning-models-in-production
# 1089 introduccion-al-procesamiento-de-lenguaje-natural
# 1090 excel-essentials-es
# 1091 1984-versus-nlp
# 1092 understanding-visualization-data
# 1093 data-scientists-tools-ko
# 1094 text-mining
# 1095 codio-visualizing-and-communicating-results-in-python-with-jupyter
# 1096 excel-basics-data-analysis-ibm
# 1097 practical-time-series-analysis
# 1098 create-rsi-buy-signal-using-r
# 1099 dasar-dasar-analitik-data-data-data-di-mana-mana
# 1100 deep-neural-network-fr
# 1101 performing-confirmatory-data-analysis-in-r
# 1102 database-creation-and-modeling-using-mysql-workbench
# 1103 xarray
# 1104 data-collection-analytics-project
# 1105 deep-learning-computer-vision
# 1106 data-analysis-r
# 1107 getting-started-with-google-sheets
# 1108 ml-azure-machine-learning-studio
# 1109 modelo-vision-computacional-azureml
# 1110 combiner-des-donnes-de-plusieurs-tables-sql
# 1111 covid-19-detection-x-ray
# 1112 traffic-sign-classification-deep-learning
# 1113 introduccion-ciencia-de-datos-aplicada
# 1114 estrategia-marketing-digital
# 1115 googlecloud-tfx-on-google-cloud-vertex-pipelines-wz6k2
# 1116 manipulate-r-data-frames-using-sql-rstudio
# 1117 nlp-sequence-models
# 1118 evaluations-ai-applications-healthcare
# 1119 detect-mitigate-ethical-risks
# 1120 baseball-analytics
# 1121 quelques-instructions-en-php
# 1122 excel-data-visualization
# 1123 explaining-ml-models
# 1124 streaming-analytics-systems-gcp-fr
# 1125 privacidad-machine-learning
# 1126 data-analytics-for-lean-six-sigma
# 1127 digging-deeper-into-audience-reports-in-google-analytics
# 1128 cognitive-solutions-rpa-analytics
# 1129 geospatial-data-visualization-using-python-and-folium
# 1130 ai-privacy-and-convenience
# 1131 cluster-analysis
# 1132 social-media-data-analytics
# 1133 build-regression-classification-clustering-models
# 1134 machine-learning-with-python-pt
# 1135 how-use-sql-large-datasets
# 1136 building-stock-returns-heatmap-tableau
# 1137 descriptive-and-inferential-statistics-in-r
# 1138 r-programming-tidyverse
# 1139 structural-equation-model-cantonese
# 1140 mysql-information-technology
# 1141 introduction-computer-vision-watson-opencv
# 1142 sample-based-learning-methods
# 1143 predict-career-longevity
# 1144 two-major-models-of-running-containers-in-aws
# 1145 visualize-data
# 1146 gis-mapping-spatial-analysis-capstone
# 1147 generando-un-data-lake-house-con-azure-synapse-analytics
# 1148 manufacturing-simulation-r-simmer
# 1149 neural-networks-deep-learning
# 1150 sql-for-data-science-ar
# 1151 data-engineering-with-ms-azure-synapse-apache-spark-pools
# 1152 analytics-analisis-datos
# 1153 multi-echelon-simulation-rsimmer
# 1154 googlecloud-cloud-dns-traffic-steering-using-geolocation-policy-447v0
# 1155 reproducible-templates-analysis
# 1156 googlecloud-datadog-getting-started-with-the-helm-chart-10c7n
# 1157 developing-pipelines-on-dataflow
# 1158 explore-insights-from-text-analysis-using-amazon-comprehend
# 1159 crea-tu-primera-aplicacion-web-con-python-y-flask
# 1160 googlecloud-using-the-natural-language-api-with-ruby-dpnbc
# 1161 erasmus-econometrics
# 1162 analytics-business-metrics-ko
# 1163 python-statistics-financial-analysis
# 1164 python-databases-ko
# 1165 data-machine-learning
# 1166 machine-learning-big-data-apache-spark
# 1167 build-analyze-linear-regression-model-r
# 1168 calculating-descriptive-statistics-in-r
# 1169 machine-learning-projects-fr
# 1170 data-science-streamlit-python
# 1171 ethical-communication-data-driven-technologies
# 1172 prepare-clean-transform-and-load-data-using-powerbi
# 1173 python-social-network-analysis
# 1174 using-sql-string-functions-to-clean-data
# 1175 azure-machine-learning-studio-pipeline
# 1176 ml-basics-kaggle-competition-pt-br
# 1177 data-analysis-with-python-pt
# 1178 facial-expression-classification
# 1179 sql-data-science-r
# 1180 create-digital-marketing-campaign-dashboards-tableau
# 1181 machine-learning-visualization
# 1182 grundlagen-daten-uberall-daten
# 1183 feature-engineering-fr
# 1184 health-informatics-professional
# 1185 formulas-in-ms-excel-2
# 1186 machine-learning-university-admission
# 1187 machine-learning-streamlit-python
# 1188 daten-analysieren-um-fragen-zu-beantworten
# 1189 analyze-digital-marketing-spend-tableau
# 1190 googlecloud-responding-to-cloud-logging-messages-with-cloud-functions-gkmol
# 1191 diagnose-breast-cancer-python
# 1192 datenanalyse-mit-r-und-dplyr
# 1193 data-science-course-fr
# 1194 inventoryanalytics
# 1195 art-science-ml-jp
# 1196 decisoes-de-marketing-baseadas-em-dados
# 1197 data-driven-decisions-with-power-bi
# 1198 excel-essentials-ru
# 1199 data-mining-theory-practice-project
# 1200 excel-advanced-es
# 1201 time-series-features
# 1202 learning-sas-data-types-naming-conventions-and-resources
# 1203 covid19-data-visualization-using-python
# 1204 googlecloud-data-pipeline-process-stream-data-and-visualize-real-time-geos-xtp7z
# 1205 gis-capstone
# 1206 mejores-decisiones-con-business-analytics
# 1207 using-basic-formulas-functions-microsoft-excel
# 1208 large-scale-forecasting-sas-viya
# 1209 r-packages
# 1210 data-structures
# 1211 excel-advanced
# 1212 pycaret-classification
# 1213 advanced-manufacturing-enterprise
# 1214 managing-machine-learning-projects
# 1215 essential-linear-algebra-for-data-science
# 1216 les-bases-du-langage-php
# 1217 conversational-experiences-dialogflow
# 1218 bike-rental-sharing-demand-prediction-with-machine-learning
# 1219 excel-data-analysis-fundamentals
# 1220 googlecloud-explore-and-create-reports-with-data-studio-owwup
# 1221 fashion-image-classification-cnn-pytorch
# 1222 analytics-excel
# 1223 automl-datasets-ml-models
# ...
# 1592 get-started-microsoft-forms
# 1593 inteligencia-artificial-para-logistica
# 1594 series-temporales-con-deep-learning-rnn-lstm-prophet
# 1595 introduccion-deep-learning
# 1596 data-scientists-tools
# 1597 codio-visualizing-data-and-communicating-results-in-r-with-rstudio
# 1598 data-processing-with-azure
# 1599 predict-gas-guzzlers-neural-net
# 1600 apply-generative-adversarial-networks-gans
# 1601 data-analytics-methods-for-marketing
# 1602 statistical-genomics
# 1603 data-mining-project
# 1604 ai-ethics
# 1605 python-project-for-data-science
# 1606 build-a-regression-model-using-pycaret
# 1607 machine-learning-applied
# 1608 tesla-stock-price-prediction-facebook-prophet
# 1609 sas-sql
# 1610 building-candlestick-charts-tableau
# 1611 analyze-sales-data-libreoffice-base-queries
# 1612 azure-machine-learning-studio-deep-learning-inference
# 1613 formulaire-html
# 1614 sql-for-data-science
# 1615 charts-pictures-themes-styles-microsoft-excel
# 1616 data-visualization-r
# 1617 nosql-databases
# 1618 machine-learning-with-python-ar
# 1619 dataviz-project
# 1620 datascimed
# 1621 rstudio-six-sigma-monte-carlo-simulation
# 1622 tensorflow-for-ai-neural-network-representation
# 1623 loan-approval-prediction-using-neural-networks
# 1624 aprendizaje-automatico-sin-codigo-azureml-designer
# 1625 algebra-i
# 1626 linear-models
# 1627 game-theory-with-python
# 1628 multilayer-perceptron-model-keras
# 1629 machine-learning-regresion-pyspark
# 1630 business-analytics-decision-making
# 1631 debuter-imagej
# 1632 portfolio-diversification-correlation-matrix-ru
# 1633 forecasting-us-elections-mixed-effects
# 1634 machine-learning-applications
# 1635 machine-learning-with-python-ru
# 1636 data-analytics-accountancy-2
# 1637 mastering-data-analysis-with-pandas-learning-path-part-5
# 1638 shortest-paths-between-routers-using-python
# 1639 formulas-in-ms-excel-1
# 1640 introduction-to-machine-learning-in-production
# 1641 hospital-management-database-using-sql-server
# 1642 intro-to-data-analytics
# 1643 convolutional-neural-networks-tensorflow-ja
# 1644 les-expressions-regulieres-en-python
# 1645 statistical-thinking-applied-statistics
# 1646 wharton-business-financial-modeling-capstone
# 1647 usar-formulas-funciones-basicas-microsoft-excel
# 1648 googlecloud-integrating-bigquery-ml-with-dialogflow-es-chatbot-ha8yo
# 1649 sales-reporting-hubspot
# 1650 generative-deep-learning-with-tensorflow
# 1651 cloud-computing-basics
# 1652 scene-classification-gradcam
# 1653 scientific-approach-innovation-management
# 1654 interpretable-machine-learning-applications-part-3
# 1655 querying-databases-using-sql-select-statement
# 1656 cybergis
# 1657 wearable-technologies
# 1658 exploratory-data-analysis-seaborn
# 1659 machine-learning-spark-mllib-databricks
# 1660 neural-networks-random-forests
# 1661 data-literacy-capstone-evaluating-research
# 1662 python-analysis
# 1663 machine-learning-projects-ar
# 1664 finalize-a-data-science-project
# 1665 big-data-integration-processing
# 1666 trier-et-filtrer-les-donnes-en-sql
# 1667 introduction-to-pymc3
# 1668 storytelling-with-data
# 1669 simulation-models-for-decision-making
# 1670 information-visualization-applied-perception
# 1671 data-science-course
# 1672 trabajando-dask
# 1673 googlecloud-use-google-maps-api-to-visualize-bigquery-geospatial-data-rav9g
# 1674 preparing-sas-programming-certification
# 1675 query-client-data-libreoffice-base
# 1676 r-programming-ko
# 1677 getting-started-with-git-and-github
# 1678 machine-learning-interpretable-shap-p
# 1679 analyzing-and-visualizing-data-in-looker
# 1680 administracion-tecnologias-informacion
# 1681 ibm-data-topology
# 1682 data-analysis-python
# 1683 data-management
# 1684 analise-de-dados-com-programacao-em-r
# 1685 leveraging-real-time-analytics-in-slack-local-and-surveymonkey-integrations
# 1686 spreadsheets-beginner-google-sheets
# 1687 ibm-data-analyst-capstone-project
# 1688 classify-radio-signals-with-pytorch
# 1689 uva-darden-market-analytics-ar
# 1690 googlecloud-google-cloud-pub-sub-qwik-start-console-3hpm3
# 1691 portfolio-optimization-markowitz-model-ru
# 1692 modelaje-anlisis-informacin-georreferenciada
# 1693 calculus-through-data-and-modelling-integration-applications
# 1694 statistical-inferences
# 1695 serverless-data-processing-with-dataflow-foundations
# 1696 fundamentals-of-data-visualization
# 1697 clasificacion-datos-satelites-automl-pycaret
# 1698 predict-diabetes-with-a-random-forest-using-r
# 1699 working-with-subqueries-in-sql
# 1700 advanced-clinical-data-science
# 1701 cervical-cancer-risk-prediction-using-machine-learning
# 1702 introduction-genomics
# 1703 gcp-exploring-preparing-data-bigquery
# 1704 analyzing-fifa-datasets-using-pandas
# 1705 regression-modeling-practice
# 1706 machine-learning-models-in-science
# 1707 calculus-through-data-and-modelling-imits-derivatives
# 1708 google-machine-learning-jp
# 1709 googlecloud-prisma-cloud-protect-your-cloud-instance-with-host-defender-xazp2
# 1710 deep-learning-image-classifier-r
# 1711 sql-mathematical-functions
# 1712 bayesian-statistics-capstone
# 1713 automated-machine-learning-powerbi-clasificacion
# 1714 json-natural-language-processing-postgresql
# 1715 the-structured-query-language-sql
# 1716 data-literacy-what-is-it-and-why-does-it-matter
# 1717 googlecloud-getting-started-with-liquid-to-customize-the-looker-user-exper-x8yva
# 1718 managing-data-analysis-es
# 1719 handling-missing-values-r-using-tidyr
# 1720 data-manipulation-and-management-using-mysqlworkbench
# 1721 medindo-o-marketing-digital
# 1722 julia-beginners-data-science
# 1723 ml-foundations
# 1724 machine-learning-data-lifecycle-in-production
# 1725 how-create-effective-metrics
# 1726 wharton-ai-applications-people-management
# 1727 getting-started-in-google-analytics
# 1728 data-visualization-dashboards-excel-cognos
# 1729 mempersiapkan-data-untuk-eksplorasi
# 1730 google-docs-arabic
# 1731 build-automated-image-quality-inspection-using-amazon-lookout-for-vision
# 1732 einstieg-raeumliche-datenanalyse-mit-geoda
# 1733 introduction-to-microsoft-excel
# 1734 wharton-customer-analytics
# 1735 tensorflow-for-ai-applying-image-convolution
# 1736 basic-statistics-python-ttest-corr
# 1737 ocp
# 1738 comment-creer-une-connexion-a-une-base-de-donnees-sql-server
# 1739 wharton-quantitative-modeling
# 1740 introduction-statistics-python
# 1741 strategic-business-analytics
# 1742 deploy-bart-simpson-chalkboard-text-generator
# 1743 machine-learning-python-nivel-avanzado
# 1744 data-cleaning
# 1745 googlecloud-datastore-qwik-start-mjbwh
# 1746 fine-tune-bert-tensorflow
# 1747 forensic-accounting
# 1748 plots-creation-using-matplotlib-python
# 1749 googlecloud-optimizing-performance-of-lookml-queries-8ht7a
# 1750 introduction-trading-machine-learning-gcp
# 1751 analise-de-dados-quantitativos
# 1752 custom-and-conditional-formatting-in-microsoft-excel
# 1753 googlecloud-data-catalog-qwik-start-vpzkb
# 1754 azure-data-lake-storage-gen2-and-data-streaming-solution
# 1755 formatting-in-ms-excel
# 1756 preparar-datos-para-la-exploracion
# 1757 unix
# 1758 rpa-introduction
# 1759 nlp-system-architecture-and-dev-ops
# 1760 analyse-datasets-java-streams
# 1761 que-es-la-ciencia-de-datos
# 1762 ensemble-methods-machine-learning
# 1763 python-and-pandas-for-data-engineering-duke
# 1764 machine-learning-foundations-for-product-managers
# 1765 nlp-python-powerbi
# 1766 machine-learning-data-analysis
# 1767 application-of-data-analysis-in-business-with-r-programming
# 1768 adv-reproducibility-cancer-informatics
# 1769 accounting-fundamentals
# 1770 neural-style-transfer
# 1771 blue-prism-foundation-training
# 1772 tajmie-albayanat-bestekhdam-loghat-sql
# 1773 image-classification-sagemaker
# 1774 cluster-analysis-association-mining-and-model-evaluation
# 1775 prophet-timeseries-prediction
# 1776 google-machine-learning-br
# 1777 inferential-statistics
# 1778 excel-essentials
# 1779 fazer-perguntas-para-tomar-decisoes-com-base-em-dados
# 1780 engajamento-conversao-e-o-consumidor
# 1781 fundamentos-dados-dados-em-todos-os-lugares
# 1782 big-data-management
# 1783 cluster-analysis-techniques
# 1784 designexperiments
# 1785 human-factors-in-artificial-intelligence
# 1786 prediction-models-sports-data
# 1787 jhu-data-visualization-r
# 1788 importer-donnees-dans-r
# 1789 fundamentals-database-systems
# 1790 tidyverse
# 1791 data-visualization-microsoft-excel
# 1792 excel-intermediate-2
# 1793 python-optical-character-recognition-using-pytorch
# 1794 data-what-it-is-what-can-we-do-with-it
# 1795 advanced-models-for-decision-making
# 1796 googlecloud-classify-text-into-categories-with-the-natural-language-api-v14pe
# 1797 deploy-a-video-indexing-application-using-amazon-rekognition
# 1798 neural-network-visualizer
# 1799 foundations-data
# 1800 analytics-business-metrics
# 1801 getting-started-with-r
# 1802 tasfiat-w-tartib-almaelumat-biastikhdam-sql
# 1803 probability-statistics
# 1804 digital-manufacturing-design
# 1805 data-storage-microsoft-azure
# 1806 simple-linear-regression-for-the-absolute-beginner
# 1807 entrepreneurs-blockchain-technology
# 1808 python-genomics
# 1809 julia-programming
# 1810 essentials-of-ms-excel
# 1811 feature-engineering
# 1812 excel-advanced-ar
# 1813 ai
# 1814 improve-business-performance-using-ratios-arabic
# 1815 introduction-to-business-analysis-by-sheets
# 1816 marketing-analytics-with-facebook
# 1817 advanced-features-in-chatbot-rasa-framework-2
# 1818 response-surfaces-mixtures-model-building
# 1819 supply-chain-analytics
# 1820 excel-essentials-pt
# 1821 exploratory-data-analysis-python-pandas
# 1822 linear-models-2
# 1823 activity-recognition-python-tensorflow-keras
# 1824 custom-layers-keras
# 1825 learning-sas-reading-raw-data-from-fixed-columns
# 1826 basic-sentiment-analysis-tensorflow
# 1827 interpretable-machine-learning-applications-part-5
# 1828 roadmap-success-digital-manufacturing-design
# 1829 predictive-analytics-business-h2o-r
# 1830 aws-improve-java-code-amazon-codeguru
# 1831 deep-learning-methods-healthcare
# 1832 get-shape-combine-and-merge-the-datasets-using-power-bi
# 1833 classification-trees-in-python
# 1834 social-science-research-chinese-society
# 1835 introduction-to-relational-database-and-sql
# 1836 building-statistical-models-in-r-linear-regression
# 1837 analyze-city-data-r-tableau
# 1838 data-visualization-plotly-express
# 1839 descriptive-statistics-analyze-data-r
# 1840 advanced-methods-reinforcement-learning-finance
# 1841 python-machine-learning-for-investment-management
# 1842 regex-python-expressions-regulieres
# 1843 introduction-to-big-data-with-spark-hadoop
# 1844 creation-de-chaines-en-python
# 1845 intro-tensorflow-jp
# 1846 clean-explore-visualize-big-data-python-spark
# 1847 facial-expression-recognition-with-pytorch
# 1848 access-bioinformatics-databases-with-biopython
# 1849 custom-distributed-training-with-tensorflow
# 1850 optimize-machine-learning-model-performance
# 1851 deploying-a-python-data-analytics-web-app-on-heroku
# 1852 causal-inference
#     courseType                   s12nIds  \
# 0  v2.ondemand  [eYmv6d_7EeWOdA7Ea609SQ]
# 1  v2.ondemand                        []
# 2  v2.ondemand                        []
# 3  v2.ondemand                        []
# 4  v2.ondemand  [SIs8zE87EemPhBLbT0zqZA]
# 5  v2.ondemand                        []
# 6  v2.ondemand                        []
# 7  v2.ondemand                        []
# 8  v2.ondemand  [utjeMEgmEeWJSQ6Y2aPmQQ]
# 9  v2.ondemand  [3UP06qzSEeupbwow02JDpQ]
#
#                                          description  \
# 0  This course will cover the steps used in weigh...
# 1  In this 1-hour long project-based course, we w...
# 2  In this 2-hour long project-based course, you ...
# 3  Machine learning (ML) is one of the fastest gr...
# 4  This course is designed to quite literally ‘ma...
# 5  By the end of this course, learners will under...
# 6  Welcome to this project-based course on Analyz...
# 7  The Code Free Data Science class is designed f...
# 8  Accounting Analytics explores how financial st...
# 9  This course is designed for business and data ...
#
#                                          domainTypes                      id  \
# 0  [{'subdomainId': 'data-analysis', 'domainId': ...  0HiU7Oe4EeWTAQ4yevf_oQ
# 1  [{'subdomainId': 'data-analysis', 'domainId': ...  zjIfbv3pEeqRMRJTGi3b6Q
# 2  [{'subdomainId': 'data-analysis', 'domainId': ...  LuXbfNnCEeq3nQoreMGNOQ
# 3  [{'subdomainId': 'machine-learning', 'domainId...  GHxiT9MGEemYpxKNJIfVmA
# 4  [{'subdomainId': 'data-analysis', 'domainId': ...  hwvdsk86Eem0lhKc4vCNig
# 5  [{'subdomainId': 'algorithms', 'domainId': 'co...  5YCz7-zMEeeMzQrhp6Bs1g
# 6  [{'subdomainId': 'machine-learning', 'domainId...  fd3ZQRthEeqQJw6Wlm3hnw
# 7  [{'subdomainId': 'machine-learning', 'domainId...  GJT3MD6xEemL3g4W6JiGWA
# 8  [{'subdomainId': 'finance', 'domainId': 'busin...  rc5KG0aUEeWG1w6arGoEIQ
# 9  [{'subdomainId': 'data-analysis', 'domainId': ...  AW_qutKPEeux6ApRYvYN1w
#
#                                                 slug  \
# 0                                       missing-data
# 1                             cluster-analysis-rcmdr
# 2  performing-data-aggregation-using-sql-aggregat...
# 3                               aws-machine-learning
# 4                            social-network-analysis
# 5                             computer-vision-basics
# 6                        analyze-data-seaborn-python
# 7                             code-free-data-science
# 8                               accounting-analytics
# 9                    extract-transform-and-load-data
#
#                     instructorIds specializations primaryLanguages  \
# 0                       [8394050]              []             [en]
# 1                      [70333041]              []             [en]
# 2                      [40353561]              []             [en]
# 3                      [37525971]              []             [en]
# 4                       [1503466]              []             [en]
# 5            [30951525, 33716827]              []             [en]
# 6                      [15528766]              []             [en]
# 7                       [4972118]              []             [en]
# 8             [1937011, 14757138]              []             [en]
# 9  [73411398, 19542214, 50069859]              []             [en]
#
#    partnerIds  ... ratings_count num_enrolled          difficulty  length  \
# 0        [32]  ...           119        10404                None      18
# 1       [565]  ...          None         None                None    None
# 2       [565]  ...            58         2657                None    None
# 3       [338]  ...          6218       191477  Intermediate Level       9
# 4        [83]  ...           179        11250      Beginner Level      10
# 5  [458, 117]  ...          1738        71144  Intermediate Level      13
# 6       [565]  ...           171         4122                None    None
# 7        [53]  ...           165        20062      Beginner Level      14
# 8         [6]  ...          2811        96638                None      10
# 9       [639]  ...          None         None  Intermediate Level      15
#
#   ins_stars ins_ratings_count ins_learners_count ins_courses_count  \
# 0      3.57                 7              13999                 5
# 1      None              None               3340              None
# 2      None              None              20863              None
# 3      4.53              1809             453721                 5
# 4      4.78                49              36006                 5
# 5      4.28               400              74032                 4
# 6         5                 7             139004              None
# 7      4.28                88             195893                 4
# 8      4.67               174             363139                 5
# 9      None              None               2506                 6
#
#   content_rating content_ratings_count
# 0           None                  None
# 1           None                  None
# 2           None                  None
# 3            94%                  9896
# 4           None                  None
# 5            96%                  8116
# 6           None                  None
# 7            92%                  1187
# 8            92%                  5673
# 9           None                  None
#
# [10 rows x 29 columns]

# %% [markdown]
# # Reorder columns

# %%
cols = df.columns.tolist()
print(cols)
print(len(cols))
# Out:
# ['courseType', 's12nIds', 'description', 'domainTypes', 'id', 'slug', 'instructorIds', 'specializations', 'primaryLanguages', 'partnerIds', 'certificates', 'name', 'subtitleLanguages', 'startDate', 'domain1', 'subdomain1', 'domain2', 'subdomain2', 'stars', 'ratings_count', 'num_enrolled', 'difficulty', 'length', 'ins_stars', 'ins_ratings_count', 'ins_learners_count', 'ins_courses_count', 'content_rating', 'content_ratings_count']
# 29

# %%
# rearrange columns, dropped the nested domainTypes column
cols = ['name', 'slug', 'domain1', 'subdomain1', 'domain2', 'subdomain2', 'description', 'startDate', 'partnerIds', 'instructorIds', 'primaryLanguages', 'subtitleLanguages', 'specializations', 'certificates', 'courseType', 'id', 's12nIds', 'stars', 'ratings_count', 'num_enrolled', 'difficulty', 'length', 'ins_stars', 'ins_ratings_count', 'ins_learners_count', 'ins_courses_count', 'content_rating', 'content_ratings_count']
print(len(cols))
# Out:
# 28

# %%
df = df[cols]
df.to_csv('courses_DS.csv', index=False)
df.head()
# Out:
#                                                 name  \
# 0                          Dealing With Missing Data
# 1                       Cluster Analysis using RCmdr
# 2  Performing Data Aggregation using SQL Aggregat...
# 3          Getting Started with AWS Machine Learning
# 4                            Social Network Analysis
#
#                                                 slug       domain1  \
# 0                                       missing-data  data-science
# 1                             cluster-analysis-rcmdr  data-science
# 2  performing-data-aggregation-using-sql-aggregat...  data-science
# 3                               aws-machine-learning  data-science
# 4                            social-network-analysis  data-science
#
#          subdomain1                 domain2              subdomain2  \
# 0     data-analysis         social-sciences  governance-and-society
# 1     data-analysis
# 2     data-analysis  information-technology         data-management
# 3  machine-learning        computer-science    software-development
# 4     data-analysis         social-sciences               education
#
#                                          description      startDate  \
# 0  This course will cover the steps used in weigh...  1471901099812
# 1  In this 1-hour long project-based course, we w...  1601055478420
# 2  In this 2-hour long project-based course, you ...  1597188408088
# 3  Machine learning (ML) is one of the fastest gr...  1568841469010
# 4  This course is designed to quite literally ‘ma...  1576005639598
#
#   partnerIds instructorIds  ... ratings_count num_enrolled  \
# 0       [32]     [8394050]  ...           119        10404
# 1      [565]    [70333041]  ...          None         None
# 2      [565]    [40353561]  ...            58         2657
# 3      [338]    [37525971]  ...          6218       191477
# 4       [83]     [1503466]  ...           179        11250
#
#            difficulty length ins_stars ins_ratings_count ins_learners_count  \
# 0                None     18      3.57                 7              13999
# 1                None   None      None              None               3340
# 2                None   None      None              None              20863
# 3  Intermediate Level      9      4.53              1809             453721
# 4      Beginner Level     10      4.78                49              36006
#
#   ins_courses_count content_rating content_ratings_count
# 0                 5           None                  None
# 1              None           None                  None
# 2              None           None                  None
# 3                 5            94%                  9896
# 4                 5           None                  None
#
# [5 rows x 28 columns]
